# %% [markdown]
# # Premier League Scores & Fixtures Scraper
#
# This notebook scrapes match results and fixture information from FBRef for Premier League teams.
#
# ## Imports and Setup

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re
from urllib.parse import urljoin, urlparse

# Headers to appear more like a regular browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

def get_page(url):
    """Fetch page with error handling and rate limiting"""
    time.sleep(random.uniform(2, 4))  # Be respectful - random delay
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None
# Out:
# c:\Users\50230\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def load_teams_from_json(json_filename):
    """
    Load teams data from JSON file
    
    Args:
        json_filename (str): Path to JSON file
    
    Returns:
        dict: Teams data dictionary
    """
    with open(json_filename, 'r', encoding='utf-8') as f:
        teams_data = json.load(f)

    return teams_data

# Load the teams data
all_teams = load_teams_from_json('../../data/raw/all_teams.json')

# Now you can use all_teams for wage extraction
print(f"Loaded {len(all_teams)} teams from JSON file")
# Out:
# Loaded 27 teams from JSON file

# %%
def extract_scores_fixtures(team_id, season, team_name):
    """
    Extract scores and fixtures information for a team in a specific season
    
    Args:
        team_id (str): FBRef team ID (e.g., 'b8fd03ef')
        season (str): Season in format '2023-2024'
        team_name (str): Team name for URL construction
    
    Returns:
        dict: Dictionary containing match data
    """
    # Construct the team fixtures URL
    team_name_url = team_name.replace(' ', '-').replace("'", "")
    url = f"https://fbref.com/en/squads/{team_id}/{season}/all_comps/{team_name_url}-Stats-All-Competitions"

    print(f"Fetching fixtures for {team_name} ({season})...")
    print(f"URL: {url}")
    
    soup = get_page(url)
    if not soup:
        return {}
    
    # Look for fixtures table - uses 'matchlogs_for' table ID
    fixtures_table = soup.find('table', {'id': 'matchlogs_for'})
    
    if not fixtures_table:
        print(f"No fixtures table found for {team_name} ({season})")
        return {}
    
    print(f"Found fixtures table")
    
    # Initialize fixtures data structure
    fixtures_data = {
        'team_id': team_id,
        'team_name': team_name,
        'season': season,
        'matches': []
    }
    
    # Process fixtures table
    tbody = fixtures_table.find('tbody')
    if tbody:
        rows = tbody.find_all('tr')
    else:
        rows = fixtures_table.find_all('tr')
        # Filter out header rows
        rows = [row for row in rows if row.find('td')]
    
    print(f"Found {len(rows)} fixture rows")
    
    for row in rows:
        match_data = {}
        
        # Extract all available data columns
        cells = row.find_all(['td', 'th'])
        for cell in cells:
            data_stat = cell.get('data-stat')
            if data_stat:
                cell_text = cell.text.strip()
                if cell_text and cell_text != '':
                    match_data[data_stat] = cell_text
                    
                # Special handling for links (opponent, competition, etc.)
                cell_link = cell.find('a')
                if cell_link and data_stat:
                    href = cell_link.get('href')
                    if href:
                        match_data[f"{data_stat}_href"] = href
        
        # Only add match if we have meaningful data
        if match_data.get('date') or match_data.get('opponent'):
            fixtures_data['matches'].append(match_data)
    
    print(f"Total extracted: {len(fixtures_data['matches'])} matches")
    return fixtures_data

# %%
def extract_all_team_fixtures(all_teams_dict):
    """
    Extract fixtures data for all teams across all seasons they played
    
    Args:
        all_teams_dict (dict): Dictionary containing team information with seasons
    
    Returns:
        dict: Complete fixtures dataset organized by team_id and season
    """
    all_fixtures_data = {}
    total_extractions = sum(len(team_info['seasons']) for team_info in all_teams_dict.values())
    current_extraction = 0
    
    print(f"Starting fixtures extraction for {len(all_teams_dict)} teams across {total_extractions} team-season combinations...")
    print("=" * 80)
    
    for team_id, team_info in all_teams_dict.items():
        team_name = team_info['team_name']
        seasons = team_info['seasons']
        
        print(f"\n🏟️  Processing {team_name} (ID: {team_id})")
        print(f"   Seasons to extract: {seasons}")
        
        # Initialize team entry in results
        if team_id not in all_fixtures_data:
            all_fixtures_data[team_id] = {
                'team_name': team_name,
                'team_id': team_id,
                'seasons_data': {}
            }
        
        # Extract fixtures for each season this team played
        for season in seasons:
            current_extraction += 1
            print(f"\n   📊 [{current_extraction}/{total_extractions}] Extracting {season}...")
            
            try:
                season_fixtures = extract_scores_fixtures(team_id, season, team_name)
                
                if season_fixtures and season_fixtures.get('matches'):
                    all_fixtures_data[team_id]['seasons_data'][season] = season_fixtures
                    match_count = len(season_fixtures['matches'])
                    print(f"   ✅ Success: {match_count} matches")
                else:
                    print(f"   ⚠️  No fixture data found for {team_name} in {season}")
                    all_fixtures_data[team_id]['seasons_data'][season] = None
                    
            except Exception as e:
                print(f"   ❌ Error extracting {team_name} {season}: {str(e)}")
                all_fixtures_data[team_id]['seasons_data'][season] = None
            
            # Small delay to be respectful to the server
            time.sleep(1)
    
    # Summary statistics
    successful_extractions = 0
    total_matches = 0
    
    for team_data in all_fixtures_data.values():
        for season_data in team_data['seasons_data'].values():
            if season_data and season_data.get('matches'):
                successful_extractions += 1
                total_matches += len(season_data['matches'])
    
    print("\n" + "=" * 80)
    print("📈 EXTRACTION SUMMARY:")
    print(f"   Total teams processed: {len(all_fixtures_data)}")
    print(f"   Successful extractions: {successful_extractions}/{total_extractions}")
    print(f"   Total match records: {total_matches}")
    print("=" * 80)
    
    return all_fixtures_data

# %%
def save_fixtures_data(fixtures_data, filename):
    """
    Save fixtures data to JSON file with proper serialization
    """
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(fixtures_data, f, indent=2, ensure_ascii=False)
    
    print(f"Fixtures data saved to {filename}")

# %%
def fixtures_data_to_dataframe(fixtures_data):
    """
    Convert fixtures data dictionary to a pandas DataFrame
    
    Args:
        fixtures_data (dict): Fixtures data from extract_all_team_fixtures()
    
    Returns:
        pd.DataFrame: Flattened DataFrame with one row per match
    """
    all_records = []
    
    for team_id, team_data in fixtures_data.items():
        team_name = team_data['team_name']
        
        for season, season_data in team_data['seasons_data'].items():
            if season_data and season_data.get('matches'):
                
                for match in season_data['matches']:
                    # Create a record for each match
                    record = {
                        'team_id': team_id,
                        'team_name': team_name,
                        'season': season
                    }
                    
                    # Add all match data
                    record.update(match)
                    all_records.append(record)
    
    # Create DataFrame
    df = pd.DataFrame(all_records)
    
    # Reorder columns to match FBRef table structure
    if len(df) > 0:
        # First the team identification columns
        team_columns = ['team_name', 'season', 'team_id']
        
        # Then the actual FBRef fixtures table columns in order
        fixtures_columns = [
            'date', 'time', 'comp','round', 'day', 'venue', 'result', 
            'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 
            'attendance', 'captain', 'formation', 'formation_opp', 
            'referee', 'match_report', 'notes'
        ]
        
        # Include any additional columns (like href links)
        available_team_cols = [col for col in team_columns if col in df.columns]
        available_fixtures_cols = [col for col in fixtures_columns if col in df.columns]
        other_columns = [col for col in df.columns if col not in team_columns + fixtures_columns]
        
        # Final column order
        final_columns = available_team_cols + available_fixtures_cols + other_columns
        df = df[final_columns]
    
    return df

# %%
def load_fixtures_json_to_dataframe(json_filename):
    """
    Load fixtures data from JSON file and convert to DataFrame
    
    Args:
        json_filename (str): Path to JSON file
    
    Returns:
        pd.DataFrame: Fixtures data as DataFrame
    """
    with open(json_filename, 'r', encoding='utf-8') as f:
        fixtures_data = json.load(f)
    
    return fixtures_data_to_dataframe(fixtures_data)

# %% [markdown]
# ## Execute Fixtures Extraction
#
# **WARNING**: This will take a significant amount of time as it needs to scrape fixture data for all teams across all seasons.

# %%
# Uncomment to run full extraction for all teams:
complete_fixtures_dataset = extract_all_team_fixtures(all_teams)

# Save to JSON
save_fixtures_data(complete_fixtures_dataset, '../../data/raw/all_competitions_fixtures_2019_2025.json')

# Convert to DataFrame
fixtures_df = fixtures_data_to_dataframe(complete_fixtures_dataset)
print(f"DataFrame shape: {fixtures_df.shape}")
print(f"Columns: {list(fixtures_df.columns)}")
fixtures_df.head()
# Out:
# Starting fixtures extraction for 27 teams across 120 team-season combinations...
# ================================================================================
#
# 🏟️  Processing Arsenal (ID: 18bb7c10)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [1/120] Extracting 2019-2020...
# Fetching fixtures for Arsenal (2019-2020)...
# URL: https://fbref.com/en/squads/18bb7c10/2019-2020/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 54 fixture rows
# Total extracted: 54 matches
#    ✅ Success: 54 matches
#
#    📊 [2/120] Extracting 2020-2021...
# Fetching fixtures for Arsenal (2020-2021)...
# URL: https://fbref.com/en/squads/18bb7c10/2020-2021/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 58 fixture rows
# Total extracted: 58 matches
#    ✅ Success: 58 matches
#
#    📊 [3/120] Extracting 2021-2022...
# Fetching fixtures for Arsenal (2021-2022)...
# URL: https://fbref.com/en/squads/18bb7c10/2021-2022/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [4/120] Extracting 2022-2023...
# Fetching fixtures for Arsenal (2022-2023)...
# URL: https://fbref.com/en/squads/18bb7c10/2022-2023/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 49 fixture rows
# Total extracted: 49 matches
#    ✅ Success: 49 matches
#
#    📊 [5/120] Extracting 2023-2024...
# Fetching fixtures for Arsenal (2023-2024)...
# URL: https://fbref.com/en/squads/18bb7c10/2023-2024/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 52 fixture rows
# Total extracted: 52 matches
#    ✅ Success: 52 matches
#
#    📊 [6/120] Extracting 2024-2025...
# Fetching fixtures for Arsenal (2024-2025)...
# URL: https://fbref.com/en/squads/18bb7c10/2024-2025/all_comps/Arsenal-Stats-All-Competitions
# Found fixtures table
# Found 58 fixture rows
# Total extracted: 58 matches
#    ✅ Success: 58 matches
#
# 🏟️  Processing Aston Villa (ID: 8602292d)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [7/120] Extracting 2019-2020...
# Fetching fixtures for Aston Villa (2019-2020)...
# URL: https://fbref.com/en/squads/8602292d/2019-2020/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 46 fixture rows
# Total extracted: 46 matches
#    ✅ Success: 46 matches
#
#    📊 [8/120] Extracting 2020-2021...
# Fetching fixtures for Aston Villa (2020-2021)...
# URL: https://fbref.com/en/squads/8602292d/2020-2021/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [9/120] Extracting 2021-2022...
# Fetching fixtures for Aston Villa (2021-2022)...
# URL: https://fbref.com/en/squads/8602292d/2021-2022/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [10/120] Extracting 2022-2023...
# Fetching fixtures for Aston Villa (2022-2023)...
# URL: https://fbref.com/en/squads/8602292d/2022-2023/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [11/120] Extracting 2023-2024...
# Fetching fixtures for Aston Villa (2023-2024)...
# URL: https://fbref.com/en/squads/8602292d/2023-2024/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 56 fixture rows
# Total extracted: 56 matches
#    ✅ Success: 56 matches
#
#    📊 [12/120] Extracting 2024-2025...
# Fetching fixtures for Aston Villa (2024-2025)...
# URL: https://fbref.com/en/squads/8602292d/2024-2025/all_comps/Aston-Villa-Stats-All-Competitions
# Found fixtures table
# Found 57 fixture rows
# Total extracted: 57 matches
#    ✅ Success: 57 matches
#
# 🏟️  Processing Bournemouth (ID: 4ba7cbea)
#    Seasons to extract: ['2019-2020', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [13/120] Extracting 2019-2020...
# Fetching fixtures for Bournemouth (2019-2020)...
# URL: https://fbref.com/en/squads/4ba7cbea/2019-2020/all_comps/Bournemouth-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [14/120] Extracting 2022-2023...
# Fetching fixtures for Bournemouth (2022-2023)...
# URL: https://fbref.com/en/squads/4ba7cbea/2022-2023/all_comps/Bournemouth-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [15/120] Extracting 2023-2024...
# Fetching fixtures for Bournemouth (2023-2024)...
# URL: https://fbref.com/en/squads/4ba7cbea/2023-2024/all_comps/Bournemouth-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [16/120] Extracting 2024-2025...
# Fetching fixtures for Bournemouth (2024-2025)...
# URL: https://fbref.com/en/squads/4ba7cbea/2024-2025/all_comps/Bournemouth-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
# 🏟️  Processing Brighton (ID: d07537b9)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [17/120] Extracting 2019-2020...
# Fetching fixtures for Brighton (2019-2020)...
# URL: https://fbref.com/en/squads/d07537b9/2019-2020/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [18/120] Extracting 2020-2021...
# Fetching fixtures for Brighton (2020-2021)...
# URL: https://fbref.com/en/squads/d07537b9/2020-2021/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [19/120] Extracting 2021-2022...
# Fetching fixtures for Brighton (2021-2022)...
# URL: https://fbref.com/en/squads/d07537b9/2021-2022/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [20/120] Extracting 2022-2023...
# Fetching fixtures for Brighton (2022-2023)...
# URL: https://fbref.com/en/squads/d07537b9/2022-2023/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 46 fixture rows
# Total extracted: 46 matches
#    ✅ Success: 46 matches
#
#    📊 [21/120] Extracting 2023-2024...
# Fetching fixtures for Brighton (2023-2024)...
# URL: https://fbref.com/en/squads/d07537b9/2023-2024/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 50 fixture rows
# Total extracted: 50 matches
#    ✅ Success: 50 matches
#
#    📊 [22/120] Extracting 2024-2025...
# Fetching fixtures for Brighton (2024-2025)...
# URL: https://fbref.com/en/squads/d07537b9/2024-2025/all_comps/Brighton-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
# 🏟️  Processing Burnley (ID: 943e8050)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2023-2024']
#
#    📊 [23/120] Extracting 2019-2020...
# Fetching fixtures for Burnley (2019-2020)...
# URL: https://fbref.com/en/squads/943e8050/2019-2020/all_comps/Burnley-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [24/120] Extracting 2020-2021...
# Fetching fixtures for Burnley (2020-2021)...
# URL: https://fbref.com/en/squads/943e8050/2020-2021/all_comps/Burnley-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [25/120] Extracting 2021-2022...
# Fetching fixtures for Burnley (2021-2022)...
# URL: https://fbref.com/en/squads/943e8050/2021-2022/all_comps/Burnley-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [26/120] Extracting 2023-2024...
# Fetching fixtures for Burnley (2023-2024)...
# URL: https://fbref.com/en/squads/943e8050/2023-2024/all_comps/Burnley-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
# 🏟️  Processing Chelsea (ID: cff3d9bb)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [27/120] Extracting 2019-2020...
# Fetching fixtures for Chelsea (2019-2020)...
# URL: https://fbref.com/en/squads/cff3d9bb/2019-2020/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 55 fixture rows
# Total extracted: 55 matches
#    ✅ Success: 55 matches
#
#    📊 [28/120] Extracting 2020-2021...
# Fetching fixtures for Chelsea (2020-2021)...
# URL: https://fbref.com/en/squads/cff3d9bb/2020-2021/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 59 fixture rows
# Total extracted: 59 matches
#    ✅ Success: 59 matches
#
#    📊 [29/120] Extracting 2021-2022...
# Fetching fixtures for Chelsea (2021-2022)...
# URL: https://fbref.com/en/squads/cff3d9bb/2021-2022/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 61 fixture rows
# Total extracted: 61 matches
#    ✅ Success: 61 matches
#
#    📊 [30/120] Extracting 2022-2023...
# Fetching fixtures for Chelsea (2022-2023)...
# URL: https://fbref.com/en/squads/cff3d9bb/2022-2023/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 50 fixture rows
# Total extracted: 50 matches
#    ✅ Success: 50 matches
#
#    📊 [31/120] Extracting 2023-2024...
# Fetching fixtures for Chelsea (2023-2024)...
# URL: https://fbref.com/en/squads/cff3d9bb/2023-2024/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 51 fixture rows
# Total extracted: 51 matches
#    ✅ Success: 51 matches
#
#    📊 [32/120] Extracting 2024-2025...
# Fetching fixtures for Chelsea (2024-2025)...
# URL: https://fbref.com/en/squads/cff3d9bb/2024-2025/all_comps/Chelsea-Stats-All-Competitions
# Found fixtures table
# Found 57 fixture rows
# Total extracted: 57 matches
#    ✅ Success: 57 matches
#
# 🏟️  Processing Crystal Palace (ID: 47c64c55)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [33/120] Extracting 2019-2020...
# Fetching fixtures for Crystal Palace (2019-2020)...
# URL: https://fbref.com/en/squads/47c64c55/2019-2020/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 40 fixture rows
# Total extracted: 40 matches
#    ✅ Success: 40 matches
#
#    📊 [34/120] Extracting 2020-2021...
# Fetching fixtures for Crystal Palace (2020-2021)...
# URL: https://fbref.com/en/squads/47c64c55/2020-2021/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 40 fixture rows
# Total extracted: 40 matches
#    ✅ Success: 40 matches
#
#    📊 [35/120] Extracting 2021-2022...
# Fetching fixtures for Crystal Palace (2021-2022)...
# URL: https://fbref.com/en/squads/47c64c55/2021-2022/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [36/120] Extracting 2022-2023...
# Fetching fixtures for Crystal Palace (2022-2023)...
# URL: https://fbref.com/en/squads/47c64c55/2022-2023/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [37/120] Extracting 2023-2024...
# Fetching fixtures for Crystal Palace (2023-2024)...
# URL: https://fbref.com/en/squads/47c64c55/2023-2024/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [38/120] Extracting 2024-2025...
# Fetching fixtures for Crystal Palace (2024-2025)...
# URL: https://fbref.com/en/squads/47c64c55/2024-2025/all_comps/Crystal-Palace-Stats-All-Competitions
# Found fixtures table
# Found 48 fixture rows
# Total extracted: 48 matches
#    ✅ Success: 48 matches
#
# 🏟️  Processing Everton (ID: d3fd31cc)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [39/120] Extracting 2019-2020...
# Fetching fixtures for Everton (2019-2020)...
# URL: https://fbref.com/en/squads/d3fd31cc/2019-2020/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [40/120] Extracting 2020-2021...
# Fetching fixtures for Everton (2020-2021)...
# URL: https://fbref.com/en/squads/d3fd31cc/2020-2021/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 46 fixture rows
# Total extracted: 46 matches
#    ✅ Success: 46 matches
#
#    📊 [41/120] Extracting 2021-2022...
# Fetching fixtures for Everton (2021-2022)...
# URL: https://fbref.com/en/squads/d3fd31cc/2021-2022/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [42/120] Extracting 2022-2023...
# Fetching fixtures for Everton (2022-2023)...
# URL: https://fbref.com/en/squads/d3fd31cc/2022-2023/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [43/120] Extracting 2023-2024...
# Fetching fixtures for Everton (2023-2024)...
# URL: https://fbref.com/en/squads/d3fd31cc/2023-2024/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [44/120] Extracting 2024-2025...
# Fetching fixtures for Everton (2024-2025)...
# URL: https://fbref.com/en/squads/d3fd31cc/2024-2025/all_comps/Everton-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
# 🏟️  Processing Leicester City (ID: a2d435b3)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2024-2025']
#
#    📊 [45/120] Extracting 2019-2020...
# Fetching fixtures for Leicester City (2019-2020)...
# URL: https://fbref.com/en/squads/a2d435b3/2019-2020/all_comps/Leicester-City-Stats-All-Competitions
# Found fixtures table
# Found 48 fixture rows
# Total extracted: 48 matches
#    ✅ Success: 48 matches
#
#    📊 [46/120] Extracting 2020-2021...
# Fetching fixtures for Leicester City (2020-2021)...
# URL: https://fbref.com/en/squads/a2d435b3/2020-2021/all_comps/Leicester-City-Stats-All-Competitions
# Found fixtures table
# Found 53 fixture rows
# Total extracted: 53 matches
#    ✅ Success: 53 matches
#
#    📊 [47/120] Extracting 2021-2022...
# Fetching fixtures for Leicester City (2021-2022)...
# URL: https://fbref.com/en/squads/a2d435b3/2021-2022/all_comps/Leicester-City-Stats-All-Competitions
# Found fixtures table
# Found 58 fixture rows
# Total extracted: 58 matches
#    ✅ Success: 58 matches
#
#    📊 [48/120] Extracting 2022-2023...
# Fetching fixtures for Leicester City (2022-2023)...
# URL: https://fbref.com/en/squads/a2d435b3/2022-2023/all_comps/Leicester-City-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [49/120] Extracting 2024-2025...
# Fetching fixtures for Leicester City (2024-2025)...
# URL: https://fbref.com/en/squads/a2d435b3/2024-2025/all_comps/Leicester-City-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
# 🏟️  Processing Liverpool (ID: 822bd0ba)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [50/120] Extracting 2019-2020...
# Fetching fixtures for Liverpool (2019-2020)...
# URL: https://fbref.com/en/squads/822bd0ba/2019-2020/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 55 fixture rows
# Total extracted: 55 matches
#    ✅ Success: 55 matches
#
#    📊 [51/120] Extracting 2020-2021...
# Fetching fixtures for Liverpool (2020-2021)...
# URL: https://fbref.com/en/squads/822bd0ba/2020-2021/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 53 fixture rows
# Total extracted: 53 matches
#    ✅ Success: 53 matches
#
#    📊 [52/120] Extracting 2021-2022...
# Fetching fixtures for Liverpool (2021-2022)...
# URL: https://fbref.com/en/squads/822bd0ba/2021-2022/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 63 fixture rows
# Total extracted: 63 matches
#    ✅ Success: 63 matches
#
#    📊 [53/120] Extracting 2022-2023...
# Fetching fixtures for Liverpool (2022-2023)...
# URL: https://fbref.com/en/squads/822bd0ba/2022-2023/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 52 fixture rows
# Total extracted: 52 matches
#    ✅ Success: 52 matches
#
#    📊 [54/120] Extracting 2023-2024...
# Fetching fixtures for Liverpool (2023-2024)...
# URL: https://fbref.com/en/squads/822bd0ba/2023-2024/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 58 fixture rows
# Total extracted: 58 matches
#    ✅ Success: 58 matches
#
#    📊 [55/120] Extracting 2024-2025...
# Fetching fixtures for Liverpool (2024-2025)...
# URL: https://fbref.com/en/squads/822bd0ba/2024-2025/all_comps/Liverpool-Stats-All-Competitions
# Found fixtures table
# Found 56 fixture rows
# Total extracted: 56 matches
#    ✅ Success: 56 matches
#
# 🏟️  Processing Manchester City (ID: b8fd03ef)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [56/120] Extracting 2019-2020...
# Fetching fixtures for Manchester City (2019-2020)...
# URL: https://fbref.com/en/squads/b8fd03ef/2019-2020/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 59 fixture rows
# Total extracted: 59 matches
#    ✅ Success: 59 matches
#
#    📊 [57/120] Extracting 2020-2021...
# Fetching fixtures for Manchester City (2020-2021)...
# URL: https://fbref.com/en/squads/b8fd03ef/2020-2021/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 61 fixture rows
# Total extracted: 61 matches
#    ✅ Success: 61 matches
#
#    📊 [58/120] Extracting 2021-2022...
# Fetching fixtures for Manchester City (2021-2022)...
# URL: https://fbref.com/en/squads/b8fd03ef/2021-2022/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 58 fixture rows
# Total extracted: 58 matches
#    ✅ Success: 58 matches
#
#    📊 [59/120] Extracting 2022-2023...
# Fetching fixtures for Manchester City (2022-2023)...
# URL: https://fbref.com/en/squads/b8fd03ef/2022-2023/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 61 fixture rows
# Total extracted: 61 matches
#    ✅ Success: 61 matches
#
#    📊 [60/120] Extracting 2023-2024...
# Fetching fixtures for Manchester City (2023-2024)...
# URL: https://fbref.com/en/squads/b8fd03ef/2023-2024/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 57 fixture rows
# Total extracted: 57 matches
#    ✅ Success: 57 matches
#
#    📊 [61/120] Extracting 2024-2025...
# Fetching fixtures for Manchester City (2024-2025)...
# URL: https://fbref.com/en/squads/b8fd03ef/2024-2025/all_comps/Manchester-City-Stats-All-Competitions
# Found fixtures table
# Found 57 fixture rows
# Total extracted: 57 matches
#    ✅ Success: 57 matches
#
# 🏟️  Processing Manchester Utd (ID: 19538871)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [62/120] Extracting 2019-2020...
# Fetching fixtures for Manchester Utd (2019-2020)...
# URL: https://fbref.com/en/squads/19538871/2019-2020/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 61 fixture rows
# Total extracted: 61 matches
#    ✅ Success: 61 matches
#
#    📊 [63/120] Extracting 2020-2021...
# Fetching fixtures for Manchester Utd (2020-2021)...
# URL: https://fbref.com/en/squads/19538871/2020-2021/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 61 fixture rows
# Total extracted: 61 matches
#    ✅ Success: 61 matches
#
#    📊 [64/120] Extracting 2021-2022...
# Fetching fixtures for Manchester Utd (2021-2022)...
# URL: https://fbref.com/en/squads/19538871/2021-2022/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 49 fixture rows
# Total extracted: 49 matches
#    ✅ Success: 49 matches
#
#    📊 [65/120] Extracting 2022-2023...
# Fetching fixtures for Manchester Utd (2022-2023)...
# URL: https://fbref.com/en/squads/19538871/2022-2023/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 62 fixture rows
# Total extracted: 62 matches
#    ✅ Success: 62 matches
#
#    📊 [66/120] Extracting 2023-2024...
# Fetching fixtures for Manchester Utd (2023-2024)...
# URL: https://fbref.com/en/squads/19538871/2023-2024/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 52 fixture rows
# Total extracted: 52 matches
#    ✅ Success: 52 matches
#
#    📊 [67/120] Extracting 2024-2025...
# Fetching fixtures for Manchester Utd (2024-2025)...
# URL: https://fbref.com/en/squads/19538871/2024-2025/all_comps/Manchester-Utd-Stats-All-Competitions
# Found fixtures table
# Found 60 fixture rows
# Total extracted: 60 matches
#    ✅ Success: 60 matches
#
# 🏟️  Processing Newcastle Utd (ID: b2b47a98)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [68/120] Extracting 2019-2020...
# Fetching fixtures for Newcastle Utd (2019-2020)...
# URL: https://fbref.com/en/squads/b2b47a98/2019-2020/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [69/120] Extracting 2020-2021...
# Fetching fixtures for Newcastle Utd (2020-2021)...
# URL: https://fbref.com/en/squads/b2b47a98/2020-2021/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [70/120] Extracting 2021-2022...
# Fetching fixtures for Newcastle Utd (2021-2022)...
# URL: https://fbref.com/en/squads/b2b47a98/2021-2022/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 40 fixture rows
# Total extracted: 40 matches
#    ✅ Success: 40 matches
#
#    📊 [71/120] Extracting 2022-2023...
# Fetching fixtures for Newcastle Utd (2022-2023)...
# URL: https://fbref.com/en/squads/b2b47a98/2022-2023/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 46 fixture rows
# Total extracted: 46 matches
#    ✅ Success: 46 matches
#
#    📊 [72/120] Extracting 2023-2024...
# Fetching fixtures for Newcastle Utd (2023-2024)...
# URL: https://fbref.com/en/squads/b2b47a98/2023-2024/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 51 fixture rows
# Total extracted: 51 matches
#    ✅ Success: 51 matches
#
#    📊 [73/120] Extracting 2024-2025...
# Fetching fixtures for Newcastle Utd (2024-2025)...
# URL: https://fbref.com/en/squads/b2b47a98/2024-2025/all_comps/Newcastle-Utd-Stats-All-Competitions
# Found fixtures table
# Found 48 fixture rows
# Total extracted: 48 matches
#    ✅ Success: 48 matches
#
# 🏟️  Processing Norwich City (ID: 1c781004)
#    Seasons to extract: ['2019-2020', '2021-2022']
#
#    📊 [74/120] Extracting 2019-2020...
# Fetching fixtures for Norwich City (2019-2020)...
# URL: https://fbref.com/en/squads/1c781004/2019-2020/all_comps/Norwich-City-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [75/120] Extracting 2021-2022...
# Fetching fixtures for Norwich City (2021-2022)...
# URL: https://fbref.com/en/squads/1c781004/2021-2022/all_comps/Norwich-City-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
# 🏟️  Processing Sheffield Utd (ID: 1df6b87e)
#    Seasons to extract: ['2019-2020', '2020-2021', '2023-2024']
#
#    📊 [76/120] Extracting 2019-2020...
# Fetching fixtures for Sheffield Utd (2019-2020)...
# URL: https://fbref.com/en/squads/1df6b87e/2019-2020/all_comps/Sheffield-Utd-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [77/120] Extracting 2020-2021...
# Fetching fixtures for Sheffield Utd (2020-2021)...
# URL: https://fbref.com/en/squads/1df6b87e/2020-2021/all_comps/Sheffield-Utd-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [78/120] Extracting 2023-2024...
# Fetching fixtures for Sheffield Utd (2023-2024)...
# URL: https://fbref.com/en/squads/1df6b87e/2023-2024/all_comps/Sheffield-Utd-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
# 🏟️  Processing Southampton (ID: 33c895d4)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2024-2025']
#
#    📊 [79/120] Extracting 2019-2020...
# Fetching fixtures for Southampton (2019-2020)...
# URL: https://fbref.com/en/squads/33c895d4/2019-2020/all_comps/Southampton-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [80/120] Extracting 2020-2021...
# Fetching fixtures for Southampton (2020-2021)...
# URL: https://fbref.com/en/squads/33c895d4/2020-2021/all_comps/Southampton-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [81/120] Extracting 2021-2022...
# Fetching fixtures for Southampton (2021-2022)...
# URL: https://fbref.com/en/squads/33c895d4/2021-2022/all_comps/Southampton-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [82/120] Extracting 2022-2023...
# Fetching fixtures for Southampton (2022-2023)...
# URL: https://fbref.com/en/squads/33c895d4/2022-2023/all_comps/Southampton-Stats-All-Competitions
# Found fixtures table
# Found 47 fixture rows
# Total extracted: 47 matches
#    ✅ Success: 47 matches
#
#    📊 [83/120] Extracting 2024-2025...
# Fetching fixtures for Southampton (2024-2025)...
# URL: https://fbref.com/en/squads/33c895d4/2024-2025/all_comps/Southampton-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
# 🏟️  Processing Tottenham (ID: 361ca564)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [84/120] Extracting 2019-2020...
# Fetching fixtures for Tottenham (2019-2020)...
# URL: https://fbref.com/en/squads/361ca564/2019-2020/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 52 fixture rows
# Total extracted: 52 matches
#    ✅ Success: 52 matches
#
#    📊 [85/120] Extracting 2020-2021...
# Fetching fixtures for Tottenham (2020-2021)...
# URL: https://fbref.com/en/squads/361ca564/2020-2021/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 59 fixture rows
# Total extracted: 59 matches
#    ✅ Success: 59 matches
#
#    📊 [86/120] Extracting 2021-2022...
# Fetching fixtures for Tottenham (2021-2022)...
# URL: https://fbref.com/en/squads/361ca564/2021-2022/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 54 fixture rows
# Total extracted: 54 matches
#    ✅ Success: 54 matches
#
#    📊 [87/120] Extracting 2022-2023...
# Fetching fixtures for Tottenham (2022-2023)...
# URL: https://fbref.com/en/squads/361ca564/2022-2023/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 50 fixture rows
# Total extracted: 50 matches
#    ✅ Success: 50 matches
#
#    📊 [88/120] Extracting 2023-2024...
# Fetching fixtures for Tottenham (2023-2024)...
# URL: https://fbref.com/en/squads/361ca564/2023-2024/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [89/120] Extracting 2024-2025...
# Fetching fixtures for Tottenham (2024-2025)...
# URL: https://fbref.com/en/squads/361ca564/2024-2025/all_comps/Tottenham-Stats-All-Competitions
# Found fixtures table
# Found 60 fixture rows
# Total extracted: 60 matches
#    ✅ Success: 60 matches
#
# 🏟️  Processing Watford (ID: 2abfe087)
#    Seasons to extract: ['2019-2020', '2021-2022']
#
#    📊 [90/120] Extracting 2019-2020...
# Fetching fixtures for Watford (2019-2020)...
# URL: https://fbref.com/en/squads/2abfe087/2019-2020/all_comps/Watford-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [91/120] Extracting 2021-2022...
# Fetching fixtures for Watford (2021-2022)...
# URL: https://fbref.com/en/squads/2abfe087/2021-2022/all_comps/Watford-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
# 🏟️  Processing West Ham (ID: 7c21e445)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [92/120] Extracting 2019-2020...
# Fetching fixtures for West Ham (2019-2020)...
# URL: https://fbref.com/en/squads/7c21e445/2019-2020/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [93/120] Extracting 2020-2021...
# Fetching fixtures for West Ham (2020-2021)...
# URL: https://fbref.com/en/squads/7c21e445/2020-2021/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [94/120] Extracting 2021-2022...
# Fetching fixtures for West Ham (2021-2022)...
# URL: https://fbref.com/en/squads/7c21e445/2021-2022/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 56 fixture rows
# Total extracted: 56 matches
#    ✅ Success: 56 matches
#
#    📊 [95/120] Extracting 2022-2023...
# Fetching fixtures for West Ham (2022-2023)...
# URL: https://fbref.com/en/squads/7c21e445/2022-2023/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 57 fixture rows
# Total extracted: 57 matches
#    ✅ Success: 57 matches
#
#    📊 [96/120] Extracting 2023-2024...
# Fetching fixtures for West Ham (2023-2024)...
# URL: https://fbref.com/en/squads/7c21e445/2023-2024/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 53 fixture rows
# Total extracted: 53 matches
#    ✅ Success: 53 matches
#
#    📊 [97/120] Extracting 2024-2025...
# Fetching fixtures for West Ham (2024-2025)...
# URL: https://fbref.com/en/squads/7c21e445/2024-2025/all_comps/West-Ham-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
# 🏟️  Processing Wolves (ID: 8cec06e1)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [98/120] Extracting 2019-2020...
# Fetching fixtures for Wolves (2019-2020)...
# URL: https://fbref.com/en/squads/8cec06e1/2019-2020/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 59 fixture rows
# Total extracted: 59 matches
#    ✅ Success: 59 matches
#
#    📊 [99/120] Extracting 2020-2021...
# Fetching fixtures for Wolves (2020-2021)...
# URL: https://fbref.com/en/squads/8cec06e1/2020-2021/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [100/120] Extracting 2021-2022...
# Fetching fixtures for Wolves (2021-2022)...
# URL: https://fbref.com/en/squads/8cec06e1/2021-2022/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [101/120] Extracting 2022-2023...
# Fetching fixtures for Wolves (2022-2023)...
# URL: https://fbref.com/en/squads/8cec06e1/2022-2023/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [102/120] Extracting 2023-2024...
# Fetching fixtures for Wolves (2023-2024)...
# URL: https://fbref.com/en/squads/8cec06e1/2023-2024/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [103/120] Extracting 2024-2025...
# Fetching fixtures for Wolves (2024-2025)...
# URL: https://fbref.com/en/squads/8cec06e1/2024-2025/all_comps/Wolves-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
# 🏟️  Processing Fulham (ID: fd962109)
#    Seasons to extract: ['2020-2021', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [104/120] Extracting 2020-2021...
# Fetching fixtures for Fulham (2020-2021)...
# URL: https://fbref.com/en/squads/fd962109/2020-2021/all_comps/Fulham-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
#    📊 [105/120] Extracting 2022-2023...
# Fetching fixtures for Fulham (2022-2023)...
# URL: https://fbref.com/en/squads/fd962109/2022-2023/all_comps/Fulham-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [106/120] Extracting 2023-2024...
# Fetching fixtures for Fulham (2023-2024)...
# URL: https://fbref.com/en/squads/fd962109/2023-2024/all_comps/Fulham-Stats-All-Competitions
# Found fixtures table
# Found 46 fixture rows
# Total extracted: 46 matches
#    ✅ Success: 46 matches
#
#    📊 [107/120] Extracting 2024-2025...
# Fetching fixtures for Fulham (2024-2025)...
# URL: https://fbref.com/en/squads/fd962109/2024-2025/all_comps/Fulham-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
# 🏟️  Processing Leeds United (ID: 5bfb9659)
#    Seasons to extract: ['2020-2021', '2021-2022', '2022-2023']
#
#    📊 [108/120] Extracting 2020-2021...
# Fetching fixtures for Leeds United (2020-2021)...
# URL: https://fbref.com/en/squads/5bfb9659/2020-2021/all_comps/Leeds-United-Stats-All-Competitions
# Found fixtures table
# Found 40 fixture rows
# Total extracted: 40 matches
#    ✅ Success: 40 matches
#
#    📊 [109/120] Extracting 2021-2022...
# Fetching fixtures for Leeds United (2021-2022)...
# URL: https://fbref.com/en/squads/5bfb9659/2021-2022/all_comps/Leeds-United-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [110/120] Extracting 2022-2023...
# Fetching fixtures for Leeds United (2022-2023)...
# URL: https://fbref.com/en/squads/5bfb9659/2022-2023/all_comps/Leeds-United-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
# 🏟️  Processing West Brom (ID: 60c6b05f)
#    Seasons to extract: ['2020-2021']
#
#    📊 [111/120] Extracting 2020-2021...
# Fetching fixtures for West Brom (2020-2021)...
# URL: https://fbref.com/en/squads/60c6b05f/2020-2021/all_comps/West-Brom-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
# 🏟️  Processing Brentford (ID: cd051869)
#    Seasons to extract: ['2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [112/120] Extracting 2021-2022...
# Fetching fixtures for Brentford (2021-2022)...
# URL: https://fbref.com/en/squads/cd051869/2021-2022/all_comps/Brentford-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [113/120] Extracting 2022-2023...
# Fetching fixtures for Brentford (2022-2023)...
# URL: https://fbref.com/en/squads/cd051869/2022-2023/all_comps/Brentford-Stats-All-Competitions
# Found fixtures table
# Found 41 fixture rows
# Total extracted: 41 matches
#    ✅ Success: 41 matches
#
#    📊 [114/120] Extracting 2023-2024...
# Fetching fixtures for Brentford (2023-2024)...
# URL: https://fbref.com/en/squads/cd051869/2023-2024/all_comps/Brentford-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
#    📊 [115/120] Extracting 2024-2025...
# Fetching fixtures for Brentford (2024-2025)...
# URL: https://fbref.com/en/squads/cd051869/2024-2025/all_comps/Brentford-Stats-All-Competitions
# Found fixtures table
# Found 43 fixture rows
# Total extracted: 43 matches
#    ✅ Success: 43 matches
#
# 🏟️  Processing Nott'ham Forest (ID: e4a775cb)
#    Seasons to extract: ['2022-2023', '2023-2024', '2024-2025']
#
#    📊 [116/120] Extracting 2022-2023...
# Fetching fixtures for Nott'ham Forest (2022-2023)...
# URL: https://fbref.com/en/squads/e4a775cb/2022-2023/all_comps/Nottham-Forest-Stats-All-Competitions
# Found fixtures table
# Found 45 fixture rows
# Total extracted: 45 matches
#    ✅ Success: 45 matches
#
#    📊 [117/120] Extracting 2023-2024...
# Fetching fixtures for Nott'ham Forest (2023-2024)...
# URL: https://fbref.com/en/squads/e4a775cb/2023-2024/all_comps/Nottham-Forest-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
#    📊 [118/120] Extracting 2024-2025...
# Fetching fixtures for Nott'ham Forest (2024-2025)...
# URL: https://fbref.com/en/squads/e4a775cb/2024-2025/all_comps/Nottham-Forest-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
# 🏟️  Processing Luton Town (ID: e297cd13)
#    Seasons to extract: ['2023-2024']
#
#    📊 [119/120] Extracting 2023-2024...
# Fetching fixtures for Luton Town (2023-2024)...
# URL: https://fbref.com/en/squads/e297cd13/2023-2024/all_comps/Luton-Town-Stats-All-Competitions
# Found fixtures table
# Found 44 fixture rows
# Total extracted: 44 matches
#    ✅ Success: 44 matches
#
# 🏟️  Processing Ipswich Town (ID: b74092de)
#    Seasons to extract: ['2024-2025']
#
#    📊 [120/120] Extracting 2024-2025...
# Fetching fixtures for Ipswich Town (2024-2025)...
# URL: https://fbref.com/en/squads/b74092de/2024-2025/all_comps/Ipswich-Town-Stats-All-Competitions
# Found fixtures table
# Found 42 fixture rows
# Total extracted: 42 matches
#    ✅ Success: 42 matches
#
# ================================================================================
# 📈 EXTRACTION SUMMARY:
#    Total teams processed: 27
#    Successful extractions: 120/120
#    Total match records: 5751
# ================================================================================
# Fixtures data saved to ../../data/raw/all_competitions_fixtures_2019_2025.json
# DataFrame shape: (5751, 29)
# Columns: ['team_name', 'season', 'team_id', 'date', 'comp', 'round', 'venue', 'result', 'opponent', 'attendance', 'captain', 'formation', 'referee', 'match_report', 'notes', 'date_href', 'start_time', 'comp_href', 'round_href', 'dayofweek', 'goals_for', 'goals_against', 'opponent_href', 'xg_for', 'xg_against', 'possession', 'captain_href', 'opp_formation', 'match_report_href']
#   team_name     season   team_id        date            comp        round  \
# 0   Arsenal  2019-2020  18bb7c10  2019-08-11  Premier League  Matchweek 1
# 1   Arsenal  2019-2020  18bb7c10  2019-08-17  Premier League  Matchweek 2
# 2   Arsenal  2019-2020  18bb7c10  2019-08-24  Premier League  Matchweek 3
# 3   Arsenal  2019-2020  18bb7c10  2019-09-01  Premier League  Matchweek 4
# 4   Arsenal  2019-2020  18bb7c10  2019-09-15  Premier League  Matchweek 5
#
#   venue result       opponent attendance  ... dayofweek goals_for  \
# 0  Away      W  Newcastle Utd     47,635  ...       Sun         1
# 1  Home      W        Burnley     60,214  ...       Sat         2
# 2  Away      L      Liverpool     53,298  ...       Sat         1
# 3  Home      D      Tottenham     60,333  ...       Sun         2
# 4  Away      D        Watford     21,360  ...       Sun         2
#
#   goals_against                                      opponent_href xg_for  \
# 0             0  /en/squads/b2b47a98/2019-2020/Newcastle-United...    1.1
# 1             1        /en/squads/943e8050/2019-2020/Burnley-Stats    0.8
# 2             3      /en/squads/822bd0ba/2019-2020/Liverpool-Stats    1.0
# 3             2  /en/squads/361ca564/2019-2020/Tottenham-Hotspu...    2.4
# 4             2        /en/squads/2abfe087/2019-2020/Watford-Stats    0.8
#
#   xg_against possession                        captain_href opp_formation  \
# 0        0.4         62   /en/players/e61b8aee/Granit-Xhaka         3-5-2
# 1        1.5         67  /en/players/d4cb83cc/Nacho-Monreal         4-4-2
# 2        2.5         48   /en/players/e61b8aee/Granit-Xhaka         4-3-3
# 3        2.0         55   /en/players/e61b8aee/Granit-Xhaka       4-2-2-2
# 4        2.7         48   /en/players/e61b8aee/Granit-Xhaka       4-2-3-1
#
#                                    match_report_href
# 0  /en/matches/1405a610/Newcastle-United-Arsenal-...
# 1  /en/matches/ff7eda21/Arsenal-Burnley-August-17...
# 2  /en/matches/102b241e/Liverpool-Arsenal-August-...
# 3  /en/matches/0b6b8aaf/North-London-Derby-Arsena...
# 4  /en/matches/8257eda8/Watford-Arsenal-September...
#
# [5 rows x 29 columns]

# %%
all_fixtures = load_teams_from_json('../../data/raw/all_competitions_fixtures_2019_2024.json')

# %%
fixtures_df = fixtures_data_to_dataframe(all_fixtures)
print(f"DataFrame shape: {fixtures_df.shape}")
print(f"Columns: {list(fixtures_df.columns)}")
fixtures_df.head()
# Out:
# DataFrame shape: (4776, 29)
# Columns: ['team_name', 'season', 'team_id', 'date', 'comp', 'round', 'venue', 'result', 'opponent', 'attendance', 'captain', 'formation', 'referee', 'match_report', 'notes', 'date_href', 'start_time', 'comp_href', 'round_href', 'dayofweek', 'goals_for', 'goals_against', 'opponent_href', 'xg_for', 'xg_against', 'possession', 'captain_href', 'opp_formation', 'match_report_href']
#   team_name     season   team_id        date            comp        round  \
# 0   Arsenal  2019-2020  18bb7c10  2019-08-11  Premier League  Matchweek 1
# 1   Arsenal  2019-2020  18bb7c10  2019-08-17  Premier League  Matchweek 2
# 2   Arsenal  2019-2020  18bb7c10  2019-08-24  Premier League  Matchweek 3
# 3   Arsenal  2019-2020  18bb7c10  2019-09-01  Premier League  Matchweek 4
# 4   Arsenal  2019-2020  18bb7c10  2019-09-15  Premier League  Matchweek 5
#
#   venue result       opponent attendance  ... dayofweek goals_for  \
# 0  Away      W  Newcastle Utd     47,635  ...       Sun         1
# 1  Home      W        Burnley     60,214  ...       Sat         2
# 2  Away      L      Liverpool     53,298  ...       Sat         1
# 3  Home      D      Tottenham     60,333  ...       Sun         2
# 4  Away      D        Watford     21,360  ...       Sun         2
#
#   goals_against                                      opponent_href xg_for  \
# 0             0  /en/squads/b2b47a98/2019-2020/Newcastle-United...    1.1
# 1             1        /en/squads/943e8050/2019-2020/Burnley-Stats    0.8
# 2             3      /en/squads/822bd0ba/2019-2020/Liverpool-Stats    1.0
# 3             2  /en/squads/361ca564/2019-2020/Tottenham-Hotspu...    2.4
# 4             2        /en/squads/2abfe087/2019-2020/Watford-Stats    0.8
#
#   xg_against possession                        captain_href opp_formation  \
# 0        0.4         62   /en/players/e61b8aee/Granit-Xhaka         3-5-2
# 1        1.5         67  /en/players/d4cb83cc/Nacho-Monreal         4-4-2
# 2        2.5         48   /en/players/e61b8aee/Granit-Xhaka         4-3-3
# 3        2.0         55   /en/players/e61b8aee/Granit-Xhaka       4-2-2-2
# 4        2.7         48   /en/players/e61b8aee/Granit-Xhaka       4-2-3-1
#
#                                    match_report_href
# 0  /en/matches/1405a610/Newcastle-United-Arsenal-...
# 1  /en/matches/ff7eda21/Arsenal-Burnley-August-17...
# 2  /en/matches/102b241e/Liverpool-Arsenal-August-...
# 3  /en/matches/0b6b8aaf/North-London-Derby-Arsena...
# 4  /en/matches/8257eda8/Watford-Arsenal-September...
#
# [5 rows x 29 columns]
