# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re
from urllib.parse import urljoin, urlparse
# Out:
# c:\Users\50230\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
def load_teams_from_json(json_filename):
    """
    Load teams data from JSON file
    
    Args:
        json_filename (str): Path to JSON file
    
    Returns:
        dict: Teams data dictionary
    """
    with open(json_filename, 'r', encoding='utf-8') as f:
        teams_data = json.load(f)

    return teams_data

# Load the teams data
all_teams = load_teams_from_json('../../data/raw/all_teams.json')

# Now you can use all_teams for wage extraction
print(f"Loaded {len(all_teams)} teams from JSON file")
# Out:
# Loaded 27 teams from JSON file

# %% [markdown]
# # Premier League Team Wages Scraper
#
# This notebook contains the wage scraping functionality extracted from the team_id_mapping notebook.
# It focuses specifically on extracting wage data from FBRef for Premier League teams.

# %%
# Headers to appear more like a regular browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

def get_page(url):
    """Fetch page with error handling and rate limiting"""
    time.sleep(random.uniform(2, 4))  # Be respectful - random delay
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# %%
# Updated function to extract from both wages tables
def extract_team_wages_complete(team_id, season, team_name):
    """
    Extract wages information from both 'wages' and 'div_wages' tables
    
    Args:
        team_id (str): FBRef team ID (e.g., 'b8fd03ef')
        season (str): Season in format '2023-2024'
        team_name (str): Team name for URL construction
    
    Returns:
        dict: Dictionary containing wages data from both tables
    """
    # Construct the team stats URL
    team_name_url = team_name.replace(' ', '-').replace("'", "")
    url = f"https://fbref.com/en/squads/{team_id}/{season}/wages/{team_name_url}-Wage-Details"
    
    print(f"Fetching wages for {team_name} ({season})...")
    print(f"URL: {url}")
    
    soup = get_page(url)
    if not soup:
        return {}
    
    # Look for both wages tables
    tables_to_find = ['wages', 'div_wages']
    found_tables = {}
    
    for table_id in tables_to_find:
        table = soup.find('table', {'id': table_id})
        if table:
            found_tables[table_id] = table
            print(f"Found table: {table_id}")
    
    if not found_tables:
        print(f"No wages tables found for {team_name} ({season})")
        return {}
    
    # Initialize wages data structure
    wages_data = {
        'team_id': team_id,
        'team_name': team_name,
        'season': season,
        'players': [],
        'tables_found': list(found_tables.keys())
    }
    
    # Process each table
    for table_name, table in found_tables.items():
        print(f"\nProcessing table: {table_name}")
        
        tbody = table.find('tbody')
        if tbody:
            rows = tbody.find_all('tr')
        else:
            rows = table.find_all('tr')
            # Filter out header rows
            rows = [row for row in rows if row.find('td')]
        
        print(f"Found {len(rows)} rows in {table_name}")
        
        for row in rows:
            player_data = {'table_source': table_name}
            
            # Extract player name
            player_cell = row.find('th', {'data-stat': 'player'}) or row.find('td', {'data-stat': 'player'})
            if player_cell:
                player_link = player_cell.find('a')
                player_data['player_name'] = player_link.text.strip() if player_link else player_cell.text.strip()
            
            # Extract all available data columns
            cells = row.find_all(['td', 'th'])
            for cell in cells:
                data_stat = cell.get('data-stat')
                if data_stat and data_stat != 'player':  # Skip player as we already handled it
                    cell_text = cell.text.strip()
                    if cell_text and cell_text != '':
                        player_data[data_stat] = cell_text
            
            # Only add player if we have at least the name
            if player_data.get('player_name'):
                wages_data['players'].append(player_data)
    
    print(f"\nTotal extracted: {len(wages_data['players'])} player records")
    return wages_data

# %%
# Extract wages for all teams across all seasons
def extract_all_team_wages(all_teams_dict):
    """
    Extract wages data for all teams across all seasons they played
    
    Args:
        all_teams_dict (dict): Dictionary containing team information with seasons
    
    Returns:
        dict: Complete wages dataset organized by team_id and season
    """
    all_wages_data = {}
    total_extractions = sum(len(team_info['seasons']) for team_info in all_teams_dict.values())
    current_extraction = 0
    
    print(f"Starting wages extraction for {len(all_teams_dict)} teams across {total_extractions} team-season combinations...")
    print("=" * 80)
    
    for team_id, team_info in all_teams_dict.items():
        team_name = team_info['team_name']
        seasons = team_info['seasons']
        
        print(f"\n🏟️  Processing {team_name} (ID: {team_id})")
        print(f"   Seasons to extract: {seasons}")
        
        # Initialize team entry in results
        if team_id not in all_wages_data:
            all_wages_data[team_id] = {
                'team_name': team_name,
                'team_id': team_id,
                'seasons_data': {}
            }
        
        # Extract wages for each season this team played
        for season in seasons:
            current_extraction += 1
            print(f"\n   📊 [{current_extraction}/{total_extractions}] Extracting {season}...")
            
            try:
                season_wages = extract_team_wages_complete(team_id, season, team_name)
                
                if season_wages and season_wages.get('players'):
                    all_wages_data[team_id]['seasons_data'][season] = season_wages
                    player_count = len(season_wages['players'])
                    tables_found = season_wages.get('tables_found', [])
                    print(f"   ✅ Success: {player_count} players, tables: {tables_found}")
                else:
                    print(f"   ⚠️  No wage data found for {team_name} in {season}")
                    all_wages_data[team_id]['seasons_data'][season] = None
                    
            except Exception as e:
                print(f"   ❌ Error extracting {team_name} {season}: {str(e)}")
                all_wages_data[team_id]['seasons_data'][season] = None
            
            # Small delay to be respectful to the server
            time.sleep(1)
    
    # Summary statistics
    successful_extractions = 0
    total_players = 0
    
    for team_data in all_wages_data.values():
        for season_data in team_data['seasons_data'].values():
            if season_data and season_data.get('players'):
                successful_extractions += 1
                total_players += len(season_data['players'])
    
    print("\n" + "=" * 80)
    print("📈 EXTRACTION SUMMARY:")
    print(f"   Total teams processed: {len(all_wages_data)}")
    print(f"   Successful extractions: {successful_extractions}/{total_extractions}")
    print(f"   Total player records: {total_players}")
    print("=" * 80)
    
    return all_wages_data

# %%
# Function to save wages data to JSON file
def save_wages_data(wages_data, filename):
    """
    Save wages data to JSON file with proper serialization
    """
    # Convert sets to lists for JSON serialization
    serializable_data = {}
    for team_id, team_data in wages_data.items():
        serializable_data[team_id] = {
            'team_name': team_data['team_name'],
            'team_id': team_data['team_id'],
            'seasons_data': team_data['seasons_data']
        }
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(serializable_data, f, indent=2, ensure_ascii=False)
    
    print(f"Wages data saved to {filename}")

# %%
def wages_data_to_dataframe(wages_data):
    """
    Convert wages data dictionary to a pandas DataFrame
    
    Args:
        wages_data (dict): Wages data from extract_all_team_wages()
    
    Returns:
        pd.DataFrame: Flattened DataFrame with one row per player per season
    """
    all_records = []
    
    for team_id, team_data in wages_data.items():
        team_name = team_data['team_name']
        
        for season, season_data in team_data['seasons_data'].items():
            if season_data and season_data.get('players'):
                
                for player in season_data['players']:
                    # Create a record for each player
                    record = {
                        'team_id': team_id,
                        'team_name': team_name,
                        'season': season,
                        'tables_found': ', '.join(season_data.get('tables_found', [])),
                    }
                    
                    # Add all player data
                    record.update(player)
                    all_records.append(record)
    
    # Create DataFrame
    df = pd.DataFrame(all_records)
    
    # Reorder columns for better readability
    if len(df) > 0:
        priority_columns = ['team_name', 'season', 'player_name', 'age', 'annual_wages', 'weekly_wages']
        other_columns = [col for col in df.columns if col not in priority_columns]
        df = df[priority_columns + other_columns]
    
    return df

# %%
# Alternative: Load from JSON file and convert to DataFrame
def load_wages_json_to_dataframe(json_filename):
    """
    Load wages data from JSON file and convert to DataFrame
    
    Args:
        json_filename (str): Path to JSON file
    
    Returns:
        pd.DataFrame: Wages data as DataFrame
    """
    with open(json_filename, 'r', encoding='utf-8') as f:
        wages_data = json.load(f)
    
    return wages_data_to_dataframe(wages_data)

# %% [markdown]
# ## Usage Example
#
# To use this scraper, you need a dictionary of teams with their IDs and seasons. Here's an example of how to use it:
#
# ```python
# # Example team data structure
# all_teams = {
#     '18bb7c10': {
#         'team_name': 'Arsenal',
#         'team_id': '18bb7c10',
#         'seasons': ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024']
#     },
#     # ... more teams
# }
#
# # Extract wages for all teams
# complete_wages_dataset = extract_all_team_wages(all_teams)
#
# # Save to JSON
# save_wages_data(complete_wages_dataset, '../../data/raw/premier_league_wages_2019_2024.json')
#
# # Convert to DataFrame
# wages_df = wages_data_to_dataframe(complete_wages_dataset)
# ```

# %%
# Execute the complete wages extraction
# WARNING: This will take a significant amount of time (estimated 20-30 minutes)
# as it needs to scrape wages data for ~26 teams across ~5 seasons each

# Uncomment the line below to start the extraction:
complete_wages_dataset = extract_all_team_wages(all_teams)
save_wages_data(complete_wages_dataset,'../../data/raw/premier_league_wages_2019_2025_v2.json')
# Out:
# Starting wages extraction for 27 teams across 120 team-season combinations...
# ================================================================================
#
# 🏟️  Processing Arsenal (ID: 18bb7c10)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [1/120] Extracting 2019-2020...
# Fetching wages for Arsenal (2019-2020)...
# URL: https://fbref.com/en/squads/18bb7c10/2019-2020/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [2/120] Extracting 2020-2021...
# Fetching wages for Arsenal (2020-2021)...
# URL: https://fbref.com/en/squads/18bb7c10/2020-2021/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [3/120] Extracting 2021-2022...
# Fetching wages for Arsenal (2021-2022)...
# URL: https://fbref.com/en/squads/18bb7c10/2021-2022/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [4/120] Extracting 2022-2023...
# Fetching wages for Arsenal (2022-2023)...
# URL: https://fbref.com/en/squads/18bb7c10/2022-2023/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [5/120] Extracting 2023-2024...
# Fetching wages for Arsenal (2023-2024)...
# URL: https://fbref.com/en/squads/18bb7c10/2023-2024/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [6/120] Extracting 2024-2025...
# Fetching wages for Arsenal (2024-2025)...
# URL: https://fbref.com/en/squads/18bb7c10/2024-2025/wages/Arsenal-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
# 🏟️  Processing Aston Villa (ID: 8602292d)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [7/120] Extracting 2019-2020...
# Fetching wages for Aston Villa (2019-2020)...
# URL: https://fbref.com/en/squads/8602292d/2019-2020/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [8/120] Extracting 2020-2021...
# Fetching wages for Aston Villa (2020-2021)...
# URL: https://fbref.com/en/squads/8602292d/2020-2021/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [9/120] Extracting 2021-2022...
# Fetching wages for Aston Villa (2021-2022)...
# URL: https://fbref.com/en/squads/8602292d/2021-2022/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [10/120] Extracting 2022-2023...
# Fetching wages for Aston Villa (2022-2023)...
# URL: https://fbref.com/en/squads/8602292d/2022-2023/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [11/120] Extracting 2023-2024...
# Fetching wages for Aston Villa (2023-2024)...
# URL: https://fbref.com/en/squads/8602292d/2023-2024/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [12/120] Extracting 2024-2025...
# Fetching wages for Aston Villa (2024-2025)...
# URL: https://fbref.com/en/squads/8602292d/2024-2025/wages/Aston-Villa-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
# 🏟️  Processing Bournemouth (ID: 4ba7cbea)
#    Seasons to extract: ['2019-2020', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [13/120] Extracting 2019-2020...
# Fetching wages for Bournemouth (2019-2020)...
# URL: https://fbref.com/en/squads/4ba7cbea/2019-2020/wages/Bournemouth-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [14/120] Extracting 2022-2023...
# Fetching wages for Bournemouth (2022-2023)...
# URL: https://fbref.com/en/squads/4ba7cbea/2022-2023/wages/Bournemouth-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [15/120] Extracting 2023-2024...
# Fetching wages for Bournemouth (2023-2024)...
# URL: https://fbref.com/en/squads/4ba7cbea/2023-2024/wages/Bournemouth-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [16/120] Extracting 2024-2025...
# Fetching wages for Bournemouth (2024-2025)...
# URL: https://fbref.com/en/squads/4ba7cbea/2024-2025/wages/Bournemouth-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
# 🏟️  Processing Brighton (ID: d07537b9)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [17/120] Extracting 2019-2020...
# Fetching wages for Brighton (2019-2020)...
# URL: https://fbref.com/en/squads/d07537b9/2019-2020/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [18/120] Extracting 2020-2021...
# Fetching wages for Brighton (2020-2021)...
# URL: https://fbref.com/en/squads/d07537b9/2020-2021/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 31 rows in wages
#
# Total extracted: 31 player records
#    ✅ Success: 31 players, tables: ['wages']
#
#    📊 [19/120] Extracting 2021-2022...
# Fetching wages for Brighton (2021-2022)...
# URL: https://fbref.com/en/squads/d07537b9/2021-2022/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [20/120] Extracting 2022-2023...
# Fetching wages for Brighton (2022-2023)...
# URL: https://fbref.com/en/squads/d07537b9/2022-2023/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [21/120] Extracting 2023-2024...
# Fetching wages for Brighton (2023-2024)...
# URL: https://fbref.com/en/squads/d07537b9/2023-2024/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [22/120] Extracting 2024-2025...
# Fetching wages for Brighton (2024-2025)...
# URL: https://fbref.com/en/squads/d07537b9/2024-2025/wages/Brighton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 35 rows in wages
#
# Total extracted: 35 player records
#    ✅ Success: 35 players, tables: ['wages']
#
# 🏟️  Processing Burnley (ID: 943e8050)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2023-2024']
#
#    📊 [23/120] Extracting 2019-2020...
# Fetching wages for Burnley (2019-2020)...
# URL: https://fbref.com/en/squads/943e8050/2019-2020/wages/Burnley-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [24/120] Extracting 2020-2021...
# Fetching wages for Burnley (2020-2021)...
# URL: https://fbref.com/en/squads/943e8050/2020-2021/wages/Burnley-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [25/120] Extracting 2021-2022...
# Fetching wages for Burnley (2021-2022)...
# URL: https://fbref.com/en/squads/943e8050/2021-2022/wages/Burnley-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
#    📊 [26/120] Extracting 2023-2024...
# Fetching wages for Burnley (2023-2024)...
# URL: https://fbref.com/en/squads/943e8050/2023-2024/wages/Burnley-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 33 rows in wages
#
# Total extracted: 33 player records
#    ✅ Success: 33 players, tables: ['wages']
#
# 🏟️  Processing Chelsea (ID: cff3d9bb)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [27/120] Extracting 2019-2020...
# Fetching wages for Chelsea (2019-2020)...
# URL: https://fbref.com/en/squads/cff3d9bb/2019-2020/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [28/120] Extracting 2020-2021...
# Fetching wages for Chelsea (2020-2021)...
# URL: https://fbref.com/en/squads/cff3d9bb/2020-2021/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [29/120] Extracting 2021-2022...
# Fetching wages for Chelsea (2021-2022)...
# URL: https://fbref.com/en/squads/cff3d9bb/2021-2022/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [30/120] Extracting 2022-2023...
# Fetching wages for Chelsea (2022-2023)...
# URL: https://fbref.com/en/squads/cff3d9bb/2022-2023/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 33 rows in wages
#
# Total extracted: 33 player records
#    ✅ Success: 33 players, tables: ['wages']
#
#    📊 [31/120] Extracting 2023-2024...
# Fetching wages for Chelsea (2023-2024)...
# URL: https://fbref.com/en/squads/cff3d9bb/2023-2024/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [32/120] Extracting 2024-2025...
# Fetching wages for Chelsea (2024-2025)...
# URL: https://fbref.com/en/squads/cff3d9bb/2024-2025/wages/Chelsea-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 34 rows in wages
#
# Total extracted: 34 player records
#    ✅ Success: 34 players, tables: ['wages']
#
# 🏟️  Processing Crystal Palace (ID: 47c64c55)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [33/120] Extracting 2019-2020...
# Fetching wages for Crystal Palace (2019-2020)...
# URL: https://fbref.com/en/squads/47c64c55/2019-2020/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [34/120] Extracting 2020-2021...
# Fetching wages for Crystal Palace (2020-2021)...
# URL: https://fbref.com/en/squads/47c64c55/2020-2021/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [35/120] Extracting 2021-2022...
# Fetching wages for Crystal Palace (2021-2022)...
# URL: https://fbref.com/en/squads/47c64c55/2021-2022/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [36/120] Extracting 2022-2023...
# Fetching wages for Crystal Palace (2022-2023)...
# URL: https://fbref.com/en/squads/47c64c55/2022-2023/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [37/120] Extracting 2023-2024...
# Fetching wages for Crystal Palace (2023-2024)...
# URL: https://fbref.com/en/squads/47c64c55/2023-2024/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [38/120] Extracting 2024-2025...
# Fetching wages for Crystal Palace (2024-2025)...
# URL: https://fbref.com/en/squads/47c64c55/2024-2025/wages/Crystal-Palace-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
# 🏟️  Processing Everton (ID: d3fd31cc)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [39/120] Extracting 2019-2020...
# Fetching wages for Everton (2019-2020)...
# URL: https://fbref.com/en/squads/d3fd31cc/2019-2020/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [40/120] Extracting 2020-2021...
# Fetching wages for Everton (2020-2021)...
# URL: https://fbref.com/en/squads/d3fd31cc/2020-2021/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 32 rows in wages
#
# Total extracted: 32 player records
#    ✅ Success: 32 players, tables: ['wages']
#
#    📊 [41/120] Extracting 2021-2022...
# Fetching wages for Everton (2021-2022)...
# URL: https://fbref.com/en/squads/d3fd31cc/2021-2022/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [42/120] Extracting 2022-2023...
# Fetching wages for Everton (2022-2023)...
# URL: https://fbref.com/en/squads/d3fd31cc/2022-2023/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [43/120] Extracting 2023-2024...
# Fetching wages for Everton (2023-2024)...
# URL: https://fbref.com/en/squads/d3fd31cc/2023-2024/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [44/120] Extracting 2024-2025...
# Fetching wages for Everton (2024-2025)...
# URL: https://fbref.com/en/squads/d3fd31cc/2024-2025/wages/Everton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
# 🏟️  Processing Leicester City (ID: a2d435b3)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2024-2025']
#
#    📊 [45/120] Extracting 2019-2020...
# Fetching wages for Leicester City (2019-2020)...
# URL: https://fbref.com/en/squads/a2d435b3/2019-2020/wages/Leicester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [46/120] Extracting 2020-2021...
# Fetching wages for Leicester City (2020-2021)...
# URL: https://fbref.com/en/squads/a2d435b3/2020-2021/wages/Leicester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [47/120] Extracting 2021-2022...
# Fetching wages for Leicester City (2021-2022)...
# URL: https://fbref.com/en/squads/a2d435b3/2021-2022/wages/Leicester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [48/120] Extracting 2022-2023...
# Fetching wages for Leicester City (2022-2023)...
# URL: https://fbref.com/en/squads/a2d435b3/2022-2023/wages/Leicester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [49/120] Extracting 2024-2025...
# Fetching wages for Leicester City (2024-2025)...
# URL: https://fbref.com/en/squads/a2d435b3/2024-2025/wages/Leicester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
# 🏟️  Processing Liverpool (ID: 822bd0ba)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [50/120] Extracting 2019-2020...
# Fetching wages for Liverpool (2019-2020)...
# URL: https://fbref.com/en/squads/822bd0ba/2019-2020/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
#    📊 [51/120] Extracting 2020-2021...
# Fetching wages for Liverpool (2020-2021)...
# URL: https://fbref.com/en/squads/822bd0ba/2020-2021/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [52/120] Extracting 2021-2022...
# Fetching wages for Liverpool (2021-2022)...
# URL: https://fbref.com/en/squads/822bd0ba/2021-2022/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [53/120] Extracting 2022-2023...
# Fetching wages for Liverpool (2022-2023)...
# URL: https://fbref.com/en/squads/822bd0ba/2022-2023/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [54/120] Extracting 2023-2024...
# Fetching wages for Liverpool (2023-2024)...
# URL: https://fbref.com/en/squads/822bd0ba/2023-2024/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [55/120] Extracting 2024-2025...
# Fetching wages for Liverpool (2024-2025)...
# URL: https://fbref.com/en/squads/822bd0ba/2024-2025/wages/Liverpool-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
# 🏟️  Processing Manchester City (ID: b8fd03ef)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [56/120] Extracting 2019-2020...
# Fetching wages for Manchester City (2019-2020)...
# URL: https://fbref.com/en/squads/b8fd03ef/2019-2020/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
#    📊 [57/120] Extracting 2020-2021...
# Fetching wages for Manchester City (2020-2021)...
# URL: https://fbref.com/en/squads/b8fd03ef/2020-2021/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [58/120] Extracting 2021-2022...
# Fetching wages for Manchester City (2021-2022)...
# URL: https://fbref.com/en/squads/b8fd03ef/2021-2022/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [59/120] Extracting 2022-2023...
# Fetching wages for Manchester City (2022-2023)...
# URL: https://fbref.com/en/squads/b8fd03ef/2022-2023/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [60/120] Extracting 2023-2024...
# Fetching wages for Manchester City (2023-2024)...
# URL: https://fbref.com/en/squads/b8fd03ef/2023-2024/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
#    📊 [61/120] Extracting 2024-2025...
# Fetching wages for Manchester City (2024-2025)...
# URL: https://fbref.com/en/squads/b8fd03ef/2024-2025/wages/Manchester-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
# 🏟️  Processing Manchester Utd (ID: 19538871)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [62/120] Extracting 2019-2020...
# Fetching wages for Manchester Utd (2019-2020)...
# URL: https://fbref.com/en/squads/19538871/2019-2020/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [63/120] Extracting 2020-2021...
# Fetching wages for Manchester Utd (2020-2021)...
# URL: https://fbref.com/en/squads/19538871/2020-2021/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [64/120] Extracting 2021-2022...
# Fetching wages for Manchester Utd (2021-2022)...
# URL: https://fbref.com/en/squads/19538871/2021-2022/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [65/120] Extracting 2022-2023...
# Fetching wages for Manchester Utd (2022-2023)...
# URL: https://fbref.com/en/squads/19538871/2022-2023/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 35 rows in wages
#
# Total extracted: 35 player records
#    ✅ Success: 35 players, tables: ['wages']
#
#    📊 [66/120] Extracting 2023-2024...
# Fetching wages for Manchester Utd (2023-2024)...
# URL: https://fbref.com/en/squads/19538871/2023-2024/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [67/120] Extracting 2024-2025...
# Fetching wages for Manchester Utd (2024-2025)...
# URL: https://fbref.com/en/squads/19538871/2024-2025/wages/Manchester-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
# 🏟️  Processing Newcastle Utd (ID: b2b47a98)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [68/120] Extracting 2019-2020...
# Fetching wages for Newcastle Utd (2019-2020)...
# URL: https://fbref.com/en/squads/b2b47a98/2019-2020/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [69/120] Extracting 2020-2021...
# Fetching wages for Newcastle Utd (2020-2021)...
# URL: https://fbref.com/en/squads/b2b47a98/2020-2021/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 31 rows in wages
#
# Total extracted: 31 player records
#    ✅ Success: 31 players, tables: ['wages']
#
#    📊 [70/120] Extracting 2021-2022...
# Fetching wages for Newcastle Utd (2021-2022)...
# URL: https://fbref.com/en/squads/b2b47a98/2021-2022/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [71/120] Extracting 2022-2023...
# Fetching wages for Newcastle Utd (2022-2023)...
# URL: https://fbref.com/en/squads/b2b47a98/2022-2023/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [72/120] Extracting 2023-2024...
# Fetching wages for Newcastle Utd (2023-2024)...
# URL: https://fbref.com/en/squads/b2b47a98/2023-2024/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [73/120] Extracting 2024-2025...
# Fetching wages for Newcastle Utd (2024-2025)...
# URL: https://fbref.com/en/squads/b2b47a98/2024-2025/wages/Newcastle-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 33 rows in wages
#
# Total extracted: 33 player records
#    ✅ Success: 33 players, tables: ['wages']
#
# 🏟️  Processing Norwich City (ID: 1c781004)
#    Seasons to extract: ['2019-2020', '2021-2022']
#
#    📊 [74/120] Extracting 2019-2020...
# Fetching wages for Norwich City (2019-2020)...
# URL: https://fbref.com/en/squads/1c781004/2019-2020/wages/Norwich-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [75/120] Extracting 2021-2022...
# Fetching wages for Norwich City (2021-2022)...
# URL: https://fbref.com/en/squads/1c781004/2021-2022/wages/Norwich-City-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
# 🏟️  Processing Sheffield Utd (ID: 1df6b87e)
#    Seasons to extract: ['2019-2020', '2020-2021', '2023-2024']
#
#    📊 [76/120] Extracting 2019-2020...
# Fetching wages for Sheffield Utd (2019-2020)...
# URL: https://fbref.com/en/squads/1df6b87e/2019-2020/wages/Sheffield-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 31 rows in wages
#
# Total extracted: 31 player records
#    ✅ Success: 31 players, tables: ['wages']
#
#    📊 [77/120] Extracting 2020-2021...
# Fetching wages for Sheffield Utd (2020-2021)...
# URL: https://fbref.com/en/squads/1df6b87e/2020-2021/wages/Sheffield-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
#    📊 [78/120] Extracting 2023-2024...
# Fetching wages for Sheffield Utd (2023-2024)...
# URL: https://fbref.com/en/squads/1df6b87e/2023-2024/wages/Sheffield-Utd-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
# 🏟️  Processing Southampton (ID: 33c895d4)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2024-2025']
#
#    📊 [79/120] Extracting 2019-2020...
# Fetching wages for Southampton (2019-2020)...
# URL: https://fbref.com/en/squads/33c895d4/2019-2020/wages/Southampton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 21 rows in wages
#
# Total extracted: 21 player records
#    ✅ Success: 21 players, tables: ['wages']
#
#    📊 [80/120] Extracting 2020-2021...
# Fetching wages for Southampton (2020-2021)...
# URL: https://fbref.com/en/squads/33c895d4/2020-2021/wages/Southampton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [81/120] Extracting 2021-2022...
# Fetching wages for Southampton (2021-2022)...
# URL: https://fbref.com/en/squads/33c895d4/2021-2022/wages/Southampton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [82/120] Extracting 2022-2023...
# Fetching wages for Southampton (2022-2023)...
# URL: https://fbref.com/en/squads/33c895d4/2022-2023/wages/Southampton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [83/120] Extracting 2024-2025...
# Fetching wages for Southampton (2024-2025)...
# URL: https://fbref.com/en/squads/33c895d4/2024-2025/wages/Southampton-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 34 rows in wages
#
# Total extracted: 34 player records
#    ✅ Success: 34 players, tables: ['wages']
#
# 🏟️  Processing Tottenham (ID: 361ca564)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [84/120] Extracting 2019-2020...
# Fetching wages for Tottenham (2019-2020)...
# URL: https://fbref.com/en/squads/361ca564/2019-2020/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [85/120] Extracting 2020-2021...
# Fetching wages for Tottenham (2020-2021)...
# URL: https://fbref.com/en/squads/361ca564/2020-2021/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [86/120] Extracting 2021-2022...
# Fetching wages for Tottenham (2021-2022)...
# URL: https://fbref.com/en/squads/361ca564/2021-2022/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 21 rows in wages
#
# Total extracted: 21 player records
#    ✅ Success: 21 players, tables: ['wages']
#
#    📊 [87/120] Extracting 2022-2023...
# Fetching wages for Tottenham (2022-2023)...
# URL: https://fbref.com/en/squads/361ca564/2022-2023/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
#    📊 [88/120] Extracting 2023-2024...
# Fetching wages for Tottenham (2023-2024)...
# URL: https://fbref.com/en/squads/361ca564/2023-2024/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 32 rows in wages
#
# Total extracted: 32 player records
#    ✅ Success: 32 players, tables: ['wages']
#
#    📊 [89/120] Extracting 2024-2025...
# Fetching wages for Tottenham (2024-2025)...
# URL: https://fbref.com/en/squads/361ca564/2024-2025/wages/Tottenham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 29 rows in wages
#
# Total extracted: 29 player records
#    ✅ Success: 29 players, tables: ['wages']
#
# 🏟️  Processing Watford (ID: 2abfe087)
#    Seasons to extract: ['2019-2020', '2021-2022']
#
#    📊 [90/120] Extracting 2019-2020...
# Fetching wages for Watford (2019-2020)...
# URL: https://fbref.com/en/squads/2abfe087/2019-2020/wages/Watford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 31 rows in wages
#
# Total extracted: 31 player records
#    ✅ Success: 31 players, tables: ['wages']
#
#    📊 [91/120] Extracting 2021-2022...
# Fetching wages for Watford (2021-2022)...
# URL: https://fbref.com/en/squads/2abfe087/2021-2022/wages/Watford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
# 🏟️  Processing West Ham (ID: 7c21e445)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [92/120] Extracting 2019-2020...
# Fetching wages for West Ham (2019-2020)...
# URL: https://fbref.com/en/squads/7c21e445/2019-2020/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [93/120] Extracting 2020-2021...
# Fetching wages for West Ham (2020-2021)...
# URL: https://fbref.com/en/squads/7c21e445/2020-2021/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [94/120] Extracting 2021-2022...
# Fetching wages for West Ham (2021-2022)...
# URL: https://fbref.com/en/squads/7c21e445/2021-2022/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [95/120] Extracting 2022-2023...
# Fetching wages for West Ham (2022-2023)...
# URL: https://fbref.com/en/squads/7c21e445/2022-2023/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 23 rows in wages
#
# Total extracted: 23 player records
#    ✅ Success: 23 players, tables: ['wages']
#
#    📊 [96/120] Extracting 2023-2024...
# Fetching wages for West Ham (2023-2024)...
# URL: https://fbref.com/en/squads/7c21e445/2023-2024/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [97/120] Extracting 2024-2025...
# Fetching wages for West Ham (2024-2025)...
# URL: https://fbref.com/en/squads/7c21e445/2024-2025/wages/West-Ham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
# 🏟️  Processing Wolves (ID: 8cec06e1)
#    Seasons to extract: ['2019-2020', '2020-2021', '2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [98/120] Extracting 2019-2020...
# Fetching wages for Wolves (2019-2020)...
# URL: https://fbref.com/en/squads/8cec06e1/2019-2020/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [99/120] Extracting 2020-2021...
# Fetching wages for Wolves (2020-2021)...
# URL: https://fbref.com/en/squads/8cec06e1/2020-2021/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [100/120] Extracting 2021-2022...
# Fetching wages for Wolves (2021-2022)...
# URL: https://fbref.com/en/squads/8cec06e1/2021-2022/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [101/120] Extracting 2022-2023...
# Fetching wages for Wolves (2022-2023)...
# URL: https://fbref.com/en/squads/8cec06e1/2022-2023/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 34 rows in wages
#
# Total extracted: 34 player records
#    ✅ Success: 34 players, tables: ['wages']
#
#    📊 [102/120] Extracting 2023-2024...
# Fetching wages for Wolves (2023-2024)...
# URL: https://fbref.com/en/squads/8cec06e1/2023-2024/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
#    📊 [103/120] Extracting 2024-2025...
# Fetching wages for Wolves (2024-2025)...
# URL: https://fbref.com/en/squads/8cec06e1/2024-2025/wages/Wolves-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 33 rows in wages
#
# Total extracted: 33 player records
#    ✅ Success: 33 players, tables: ['wages']
#
# 🏟️  Processing Fulham (ID: fd962109)
#    Seasons to extract: ['2020-2021', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [104/120] Extracting 2020-2021...
# Fetching wages for Fulham (2020-2021)...
# URL: https://fbref.com/en/squads/fd962109/2020-2021/wages/Fulham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 32 rows in wages
#
# Total extracted: 32 player records
#    ✅ Success: 32 players, tables: ['wages']
#
#    📊 [105/120] Extracting 2022-2023...
# Fetching wages for Fulham (2022-2023)...
# URL: https://fbref.com/en/squads/fd962109/2022-2023/wages/Fulham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
#    📊 [106/120] Extracting 2023-2024...
# Fetching wages for Fulham (2023-2024)...
# URL: https://fbref.com/en/squads/fd962109/2023-2024/wages/Fulham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [107/120] Extracting 2024-2025...
# Fetching wages for Fulham (2024-2025)...
# URL: https://fbref.com/en/squads/fd962109/2024-2025/wages/Fulham-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 25 rows in wages
#
# Total extracted: 25 player records
#    ✅ Success: 25 players, tables: ['wages']
#
# 🏟️  Processing Leeds United (ID: 5bfb9659)
#    Seasons to extract: ['2020-2021', '2021-2022', '2022-2023']
#
#    📊 [108/120] Extracting 2020-2021...
# Fetching wages for Leeds United (2020-2021)...
# URL: https://fbref.com/en/squads/5bfb9659/2020-2021/wages/Leeds-United-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [109/120] Extracting 2021-2022...
# Fetching wages for Leeds United (2021-2022)...
# URL: https://fbref.com/en/squads/5bfb9659/2021-2022/wages/Leeds-United-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 24 rows in wages
#
# Total extracted: 24 player records
#    ✅ Success: 24 players, tables: ['wages']
#
#    📊 [110/120] Extracting 2022-2023...
# Fetching wages for Leeds United (2022-2023)...
# URL: https://fbref.com/en/squads/5bfb9659/2022-2023/wages/Leeds-United-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
# 🏟️  Processing West Brom (ID: 60c6b05f)
#    Seasons to extract: ['2020-2021']
#
#    📊 [111/120] Extracting 2020-2021...
# Fetching wages for West Brom (2020-2021)...
# URL: https://fbref.com/en/squads/60c6b05f/2020-2021/wages/West-Brom-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 32 rows in wages
#
# Total extracted: 32 player records
#    ✅ Success: 32 players, tables: ['wages']
#
# 🏟️  Processing Brentford (ID: cd051869)
#    Seasons to extract: ['2021-2022', '2022-2023', '2023-2024', '2024-2025']
#
#    📊 [112/120] Extracting 2021-2022...
# Fetching wages for Brentford (2021-2022)...
# URL: https://fbref.com/en/squads/cd051869/2021-2022/wages/Brentford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 33 rows in wages
#
# Total extracted: 33 player records
#    ✅ Success: 33 players, tables: ['wages']
#
#    📊 [113/120] Extracting 2022-2023...
# Fetching wages for Brentford (2022-2023)...
# URL: https://fbref.com/en/squads/cd051869/2022-2023/wages/Brentford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 26 rows in wages
#
# Total extracted: 26 player records
#    ✅ Success: 26 players, tables: ['wages']
#
#    📊 [114/120] Extracting 2023-2024...
# Fetching wages for Brentford (2023-2024)...
# URL: https://fbref.com/en/squads/cd051869/2023-2024/wages/Brentford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
#    📊 [115/120] Extracting 2024-2025...
# Fetching wages for Brentford (2024-2025)...
# URL: https://fbref.com/en/squads/cd051869/2024-2025/wages/Brentford-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 30 rows in wages
#
# Total extracted: 30 player records
#    ✅ Success: 30 players, tables: ['wages']
#
# 🏟️  Processing Nott'ham Forest (ID: e4a775cb)
#    Seasons to extract: ['2022-2023', '2023-2024', '2024-2025']
#
#    📊 [116/120] Extracting 2022-2023...
# Fetching wages for Nott'ham Forest (2022-2023)...
# URL: https://fbref.com/en/squads/e4a775cb/2022-2023/wages/Nottham-Forest-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 38 rows in wages
#
# Total extracted: 38 player records
#    ✅ Success: 38 players, tables: ['wages']
#
#    📊 [117/120] Extracting 2023-2024...
# Fetching wages for Nott'ham Forest (2023-2024)...
# URL: https://fbref.com/en/squads/e4a775cb/2023-2024/wages/Nottham-Forest-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 37 rows in wages
#
# Total extracted: 37 player records
#    ✅ Success: 37 players, tables: ['wages']
#
#    📊 [118/120] Extracting 2024-2025...
# Fetching wages for Nott'ham Forest (2024-2025)...
# URL: https://fbref.com/en/squads/e4a775cb/2024-2025/wages/Nottham-Forest-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 31 rows in wages
#
# Total extracted: 31 player records
#    ✅ Success: 31 players, tables: ['wages']
#
# 🏟️  Processing Luton Town (ID: e297cd13)
#    Seasons to extract: ['2023-2024']
#
#    📊 [119/120] Extracting 2023-2024...
# Fetching wages for Luton Town (2023-2024)...
# URL: https://fbref.com/en/squads/e297cd13/2023-2024/wages/Luton-Town-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 27 rows in wages
#
# Total extracted: 27 player records
#    ✅ Success: 27 players, tables: ['wages']
#
# 🏟️  Processing Ipswich Town (ID: b74092de)
#    Seasons to extract: ['2024-2025']
#
#    📊 [120/120] Extracting 2024-2025...
# Fetching wages for Ipswich Town (2024-2025)...
# URL: https://fbref.com/en/squads/b74092de/2024-2025/wages/Ipswich-Town-Wage-Details
# Found table: wages
#
# Processing table: wages
# Found 28 rows in wages
#
# Total extracted: 28 player records
#    ✅ Success: 28 players, tables: ['wages']
#
# ================================================================================
# 📈 EXTRACTION SUMMARY:
#    Total teams processed: 27
#    Successful extractions: 120/120
#    Total player records: 3341
# ================================================================================
# Wages data saved to ../../data/raw/premier_league_wages_2019_2024_v2.json

# %%
save_wages_data(complete_wages_dataset,'../../data/raw/premier_league_wages_2019_2025_v2.json')
# Out:
# Wages data saved to ../../data/raw/premier_league_wages_2019_2025_v2.json

# %%
wages_df = wages_data_to_dataframe(complete_wages_dataset)

# %%
wages_df
# Out:
#          team_name     season                player_name age  \
# 0          Arsenal  2019-2020                 Mesut Özil  30
# 1          Arsenal  2019-2020  Pierre-Emerick Aubameyang  30
# 2          Arsenal  2019-2020        Alexandre Lacazette  28
# 3          Arsenal  2019-2020            Héctor Bellerín  24
# 4          Arsenal  2019-2020                 David Luiz  32
# ...            ...        ...                        ...  ..
# 3336  Ipswich Town  2024-2025           Nathan Broadhead  26
# 3337  Ipswich Town  2024-2025           Omari Hutchinson  20
# 3338  Ipswich Town  2024-2025             Cieran Slicker  22
# 3339  Ipswich Town  2024-2025              Elkan Baggott  22
# 3340  Ipswich Town  2024-2025          Cameron Humphreys  21
#
#                                   annual_wages  \
# 0     £ 18,200,000 (€ 21,704,678, $22,117,026)
# 1     £ 13,000,000 (€ 15,503,341, $15,797,876)
# 2      £ 9,470,000 (€ 11,293,588, $11,508,145)
# 3        £ 5,720,000 (€ 6,821,470, $6,951,065)
# 4        £ 5,250,000 (€ 6,260,965, $6,379,911)
# ...                                        ...
# 3336           £ 312,000 (€ 369,641, $381,031)
# 3337           £ 312,000 (€ 369,641, $381,031)
# 3338           £ 156,000 (€ 184,821, $190,515)
# 3339             £ 78,000 (€ 91,585, $102,108)
# 3340              £ 52,000 (€ 61,056, $68,072)
#
#                          weekly_wages   team_id tables_found table_source  \
# 0     £ 350,000 (€ 417,398, $425,327)  18bb7c10        wages        wages
# 1     £ 250,000 (€ 298,141, $303,805)  18bb7c10        wages        wages
# 2     £ 182,115 (€ 217,184, $221,310)  18bb7c10        wages        wages
# 3     £ 110,000 (€ 131,182, $133,674)  18bb7c10        wages        wages
# 4     £ 100,962 (€ 120,403, $122,691)  18bb7c10        wages        wages
# ...                               ...       ...          ...          ...
# 3336        £ 6,000 (€ 7,108, $7,328)  b74092de        wages        wages
# 3337        £ 6,000 (€ 7,108, $7,328)  b74092de        wages        wages
# 3338        £ 3,000 (€ 3,554, $3,664)  b74092de        wages        wages
# 3339        £ 1,500 (€ 1,761, $1,964)  b74092de        wages        wages
# 3340        £ 1,000 (€ 1,174, $1,309)  b74092de        wages        wages
#
#      nationality position                  notes
# 0         de GER       MF                    NaN
# 1         ga GAB       FW                    NaN
# 2         fr FRA       FW                    NaN
# 3         es ESP    DF,MF                    NaN
# 4         br BRA       DF                    NaN
# ...          ...      ...                    ...
# 3336     wls WAL    MF,FW  Unverified estimation
# 3337         NaN       RW  Unverified estimation
# 3338         NaN       GK  Unverified estimation
# 3339         NaN       CB  Unverified estimation
# 3340         NaN       CM  Unverified estimation
#
# [3341 rows x 12 columns]
