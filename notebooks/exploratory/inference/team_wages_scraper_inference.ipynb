# %% [markdown]
# # Team Wages Scraper for Inference - Season 2025-2026
#
# This notebook extracts wage data specifically for the 2025-2026 season for inference purposes.
# It focuses on current team wages needed for making predictions.

# %%
import json
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re
from urllib.parse import urljoin, urlparse
# Out:
# c:\Users\50230\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Headers to appear more like a regular browser
request_headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

def get_page(url):
    """Fetch page with error handling and rate limiting"""
    time.sleep(random.uniform(2, 4))  # Be respectful - random delay
    
    try:
        response = requests.get(url, headers=request_headers)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# %%
def load_teams_for_inference():
    """
    Load teams data for 2025-2026 season inference
    Structure: team_name -> {team_name, team_id, reference}
    """
    try:
        # Try to load from inference teams file
        with open('../../../data/prod/inference/raw/all_teams.json', 'r', encoding='utf-8') as f:
            teams_data = json.load(f)
        print(f"Loaded {len(teams_data)} teams from inference file")
        
        # Show sample structure
        if teams_data:
            first_team = next(iter(teams_data.values()))
            print(f"Team structure: {first_team}")
        
        return teams_data
    except FileNotFoundError:
        print("Inference teams file not found. Please run team_id_mapping_inference first.")
        return {}

# Load teams for inference
inference_teams = load_teams_for_inference()

# Display teams available for wage scraping
if inference_teams:
    print(f"\nTeams available for wage scraping:")
    for team_name, team_info in list(inference_teams.items())[:5]:
        print(f"  {team_name}: {team_info['team_id']}")
    if len(inference_teams) > 5:
        print(f"  ... and {len(inference_teams) - 5} more teams")
# Out:
# Loaded 20 teams from inference file
# Team structure: {'team_name': 'Arsenal', 'team_id': '18bb7c10', 'reference': '/en/squads/18bb7c10/Arsenal-Stats'}
#
# Teams available for wage scraping:
#   Arsenal: 18bb7c10
#   Aston Villa: 8602292d
#   Bournemouth: 4ba7cbea
#   Brentford: cd051869
#   Brighton: d07537b9
#   ... and 15 more teams

# %%
def get_team_wages_df(team_id, team_name, season="2025-2026"):
    """
    Fetch wages data for a specific team and return as DataFrame
    
    Args:
        team_id (str): FBRef team ID (e.g., '18bb7c10')
        team_name (str): Team name (e.g., 'Arsenal')
        season (str): Season (default: '2025-2026')
    
    Returns:
        pd.DataFrame: Wages data for the team, or empty DataFrame if failed
    """
    # Construct URL
    url = f"https://fbref.com/en/squads/{team_id}/{season}/wages/{team_name}-Wage-Details"
    print(f"Fetching wages for {team_name}...")
    print(f"URL: {url}")
    
    # Make request
    soup = get_page(url)
    if not soup:
        print(f"❌ Failed to fetch page for {team_name}")
        return pd.DataFrame()
    
    # Look for wages table
    wages_table = soup.find('table', {'id': 'wages'})
    if not wages_table:
        print(f"❌ No wages table found for {team_name}")
        return pd.DataFrame()
    
    print(f"✅ Found wages table for {team_name}")
    
    # Extract table headers
    header_row = wages_table.find('thead').find('tr') if wages_table.find('thead') else wages_table.find('tr')
    column_headers = []
    
    if header_row:
        for th in header_row.find_all(['th', 'td']):
            header_text = th.text.strip()
            data_stat = th.get('data-stat', '')
            # Use data-stat if available, otherwise use text
            column_name = data_stat if data_stat else header_text
            column_headers.append(column_name)
    
    # Extract table data
    tbody = wages_table.find('tbody') if wages_table.find('tbody') else wages_table
    rows = tbody.find_all('tr')
    
    # Skip header rows if they're in tbody
    data_rows = [row for row in rows if row.find('td') or row.find('th', {'data-stat': True})]
    
    # Extract data from each row
    table_data = []
    for row in data_rows:
        row_data = []
        cells = row.find_all(['td', 'th'])
        
        for cell in cells:
            cell_text = cell.text.strip()
            row_data.append(cell_text)
        
        # Only add row if it has data
        if row_data and any(cell for cell in row_data):
            table_data.append(row_data)
    
    # Create DataFrame
    if table_data and column_headers:
        # Ensure we have the right number of columns
        max_cols = max(len(row) for row in table_data) if table_data else len(column_headers)
        
        # Pad headers if needed
        while len(column_headers) < max_cols:
            column_headers.append(f'col_{len(column_headers)}')
        
        # Pad rows if needed
        for row in table_data:
            while len(row) < len(column_headers):
                row.append('')
        
        # Create DataFrame
        df = pd.DataFrame(table_data, columns=column_headers[:max_cols])
        
        # Add team info columns
        df['team_name'] = team_name
        df['team_id'] = team_id
        df['season'] = season
        
        print(f"✅ DataFrame created with {len(df)} players")
        return df
        
    else:
        print(f"❌ No data to create DataFrame for {team_name}")
        return pd.DataFrame()

# %%
# Out:
# Fetching wages for Arsenal...
# URL: https://fbref.com/en/squads/18bb7c10/2025-2026/wages/Arsenal-Wage-Details
# ✅ Found wages table for Arsenal
# ✅ DataFrame created with 27 players
#                   player nationality position age  \
# 0            Kai Havertz      de GER       CF  26
# 1          Gabriel Jesus      br BRA       CF  28
# 2            Declan Rice     eng ENG       CM  26
# 3        Martin Ødegaard      no NOR       AM  26
# 4        Viktor Gyökeres      se SWE       CF  27
# 5            Bukayo Saka     eng ENG       RW  23
# 6         William Saliba      fr FRA       CB  24
# 7     Gabriel Martinelli      br BRA       LW  24
# 8    Oleksandr Zinchenko      ua UKR       LB  28
# 9              Ben White     eng ENG       RB  27
# 10     Gabriel Magalhães      br BRA       CB  27
# 11          Mikel Merino      es ESP       CM  29
# 12    Riccardo Calafiori      it ITA       LB  23
# 13     Takehiro Tomiyasu      jp JPN       RB  26
# 14          Reiss Nelson     eng ENG       RW  25
# 15            David Raya      es ESP       GK  29
# 16        Jurriën Timber      nl NED       RB  24
# 17      Leandro Trossard      be BEL       LW  30
# 18      Martín Zubimendi      es ESP       DM  26
# 19          Jakub Kiwior      pl POL       CB  25
# 20  Albert Sambi Lokonga      be BEL       CM  25
# 21          Fabio Vieira      pt POR       AM  25
# 22    Myles Lewis-Skelly                   LB  18
# 23       Karl Jakob Hein      ee EST       GK  23
# 24         Ethan Nwaneri                   RW  18
# 25          Noni Madueke                   RW  23
# 26     Kepa Arrizabalaga      es ESP       GK  30
#
#                        weekly_wages                              annual_wages  \
# 0   £ 280,000 (€ 321,368, $371,011)  £ 14,560,000 (€ 16,711,124, $19,292,582)
# 1   £ 265,000 (€ 304,152, $351,136)  £ 13,780,000 (€ 15,815,885, $18,259,051)
# 2   £ 240,000 (€ 275,458, $318,010)  £ 12,480,000 (€ 14,323,820, $16,536,499)
# 3   £ 240,000 (€ 275,458, $318,010)  £ 12,480,000 (€ 14,323,820, $16,536,499)
# 4   £ 200,000 (€ 229,548, $265,008)  £ 10,400,000 (€ 11,936,517, $13,780,416)
# 5   £ 195,000 (€ 223,810, $258,383)  £ 10,140,000 (€ 11,638,104, $13,435,906)
# 6   £ 190,000 (€ 218,071, $251,758)   £ 9,880,000 (€ 11,339,691, $13,091,395)
# 7   £ 180,000 (€ 206,594, $238,507)   £ 9,360,000 (€ 10,742,865, $12,402,374)
# 8   £ 150,000 (€ 172,161, $198,756)    £ 7,800,000 (€ 8,952,388, $10,335,312)
# 9   £ 150,000 (€ 172,161, $198,756)    £ 7,800,000 (€ 8,952,388, $10,335,312)
# 10  £ 150,000 (€ 172,161, $198,756)    £ 7,800,000 (€ 8,952,388, $10,335,312)
# 11  £ 130,000 (€ 149,206, $172,255)     £ 6,760,000 (€ 7,758,736, $8,957,270)
# 12  £ 120,000 (€ 137,729, $159,005)     £ 6,240,000 (€ 7,161,910, $8,268,250)
# 13  £ 100,000 (€ 114,774, $132,504)     £ 5,200,000 (€ 5,968,258, $6,890,208)
# 14  £ 100,000 (€ 114,774, $132,504)     £ 5,200,000 (€ 5,968,258, $6,890,208)
# 15  £ 100,000 (€ 114,774, $132,504)     £ 5,200,000 (€ 5,968,258, $6,890,208)
# 16   £ 90,000 (€ 103,297, $119,254)     £ 4,680,000 (€ 5,371,433, $6,201,187)
# 17   £ 90,000 (€ 103,297, $119,254)     £ 4,680,000 (€ 5,371,433, $6,201,187)
# 18     £ 75,000 (€ 86,081, $99,378)     £ 3,900,000 (€ 4,476,194, $5,167,656)
# 19     £ 58,000 (€ 66,569, $76,852)     £ 3,016,000 (€ 3,461,590, $3,996,321)
# 20     £ 50,000 (€ 57,387, $66,252)     £ 2,600,000 (€ 2,984,129, $3,445,104)
# 21     £ 45,000 (€ 51,648, $59,627)     £ 2,340,000 (€ 2,685,716, $3,100,594)
# 22     £ 40,000 (€ 45,910, $53,002)     £ 2,080,000 (€ 2,387,303, $2,756,083)
# 23     £ 10,000 (€ 11,477, $13,250)           £ 520,000 (€ 596,826, $689,021)
# 24        £ 6,000 (€ 6,886, $7,950)           £ 312,000 (€ 358,096, $413,412)
# 25
# 26
#
#                     notes team_name   team_id     season
# 0                           Arsenal  18bb7c10  2025-2026
# 1                           Arsenal  18bb7c10  2025-2026
# 2                           Arsenal  18bb7c10  2025-2026
# 3                           Arsenal  18bb7c10  2025-2026
# 4   Unverified estimation   Arsenal  18bb7c10  2025-2026
# 5                           Arsenal  18bb7c10  2025-2026
# 6                           Arsenal  18bb7c10  2025-2026
# 7                           Arsenal  18bb7c10  2025-2026
# 8                           Arsenal  18bb7c10  2025-2026
# 9   Unverified estimation   Arsenal  18bb7c10  2025-2026
# 10  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 11  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 12                          Arsenal  18bb7c10  2025-2026
# 13                          Arsenal  18bb7c10  2025-2026
# 14                          Arsenal  18bb7c10  2025-2026
# 15  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 16                          Arsenal  18bb7c10  2025-2026
# 17                          Arsenal  18bb7c10  2025-2026
# 18                          Arsenal  18bb7c10  2025-2026
# 19                          Arsenal  18bb7c10  2025-2026
# 20  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 21                          Arsenal  18bb7c10  2025-2026
# 22  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 23  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 24  Unverified estimation   Arsenal  18bb7c10  2025-2026
# 25                          Arsenal  18bb7c10  2025-2026
# 26                          Arsenal  18bb7c10  2025-2026

# %%
def get_all_teams_wages(teams_dict, season="2025-2026"):
    """
    Fetch wages data for all teams and combine into a single DataFrame
    
    Args:
        teams_dict (dict): Dictionary with structure {team_name: {team_name, team_id, reference}}
        season (str): Season (default: '2025-2026')
    
    Returns:
        pd.DataFrame: Combined wages data for all teams
    """
    all_wages_data = []
    total_teams = len(teams_dict)
    successful_extractions = 0
    failed_teams = []
    
    print(f"Starting wages extraction for {total_teams} teams...")
    print("=" * 80)
    
    for i, (team_name_key, team_info) in enumerate(teams_dict.items(), 1):
        team_name = team_info['team_name']
        team_id = team_info['team_id']
        
        print(f"\n🏟️  [{i}/{total_teams}] Processing {team_name} (ID: {team_id})")
        
        try:
            # Get wages DataFrame for this team
            team_wages_df = get_team_wages_df(team_id, team_name, season)
            
            if not team_wages_df.empty:
                all_wages_data.append(team_wages_df)
                successful_extractions += 1
                print(f"   ✅ Success: {len(team_wages_df)} players added")
            else:
                failed_teams.append(team_name)
                print(f"   ⚠️  No data found for {team_name}")
                
        except Exception as e:
            failed_teams.append(team_name)
            print(f"   ❌ Error processing {team_name}: {str(e)}")
        
        # Small delay between requests to be respectful
        if i < total_teams:  # Don't delay after the last team
            print(f"   ⏳ Waiting before next request...")
            time.sleep(1)
    
    # Combine all DataFrames
    if all_wages_data:
        print(f"\\n📊 Combining data from {len(all_wages_data)} successful extractions...")
        combined_df = pd.concat(all_wages_data, ignore_index=True)
        
        print("\\n" + "=" * 80)
        print("📈 EXTRACTION SUMMARY:")
        print(f"   Total teams processed: {total_teams}")
        print(f"   Successful extractions: {successful_extractions}")
        print(f"   Failed extractions: {len(failed_teams)}")
        print(f"   Total players in dataset: {len(combined_df)}")
        print(f"   Columns in dataset: {len(combined_df.columns)}")
        
        if failed_teams:
            print(f"\\n❌ Teams that failed: {', '.join(failed_teams)}")
        
        print("=" * 80)
        
        return combined_df
    else:
        print("\\n❌ No data was successfully extracted from any team")
        return pd.DataFrame()

# %%
# Execute wages extraction for all teams
if inference_teams:
    print("Starting extraction for all teams...")
    all_wages_df = get_all_teams_wages(inference_teams)
    
    if not all_wages_df.empty:
        print(f"\\n✅ Success! Combined wages dataset created")
        print(f"Shape: {all_wages_df.shape}")
        print(f"Columns: {list(all_wages_df.columns)}")
        
        # Save to multiple formats in inference directory
        all_wages_df.to_csv('../../../data/prod/inference/raw/all_teams_wages_2025_2026.csv', index=False)
        all_wages_df.to_parquet('../../../data/prod/inference/raw/all_teams_wages_2025_2026.parquet', index=False)
        all_wages_df.to_json('../../../data/prod/inference/raw/all_teams_wages_2025_2026.json', orient='records', indent=2)
        
        print(f"\\n💾 Data saved to inference/raw/ directory in multiple formats")
        
        # Show sample data
        print(f"\\n📋 Sample data:")
        display_cols = ['team_name', 'player', 'age', 'weekly_wages', 'annual_wages']
        available_cols = [col for col in display_cols if col in all_wages_df.columns]
        print(all_wages_df[available_cols].head(10))
        
    else:
        print(f"\\n❌ No data was extracted")
else:
    print("❌ No teams data available. Please load teams first.")
# Out:
# Starting extraction for all teams...
# Starting wages extraction for 20 teams...
# ================================================================================
#
# 🏟️  [1/20] Processing Arsenal (ID: 18bb7c10)
# Fetching wages for Arsenal...
# URL: https://fbref.com/en/squads/18bb7c10/2025-2026/wages/Arsenal-Wage-Details
# ✅ Found wages table for Arsenal
# ✅ DataFrame created with 27 players
#    ✅ Success: 27 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [2/20] Processing Aston Villa (ID: 8602292d)
# Fetching wages for Aston Villa...
# URL: https://fbref.com/en/squads/8602292d/2025-2026/wages/Aston Villa-Wage-Details
# ✅ Found wages table for Aston Villa
# ✅ DataFrame created with 30 players
#    ✅ Success: 30 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [3/20] Processing Bournemouth (ID: 4ba7cbea)
# Fetching wages for Bournemouth...
# URL: https://fbref.com/en/squads/4ba7cbea/2025-2026/wages/Bournemouth-Wage-Details
# ✅ Found wages table for Bournemouth
# ✅ DataFrame created with 31 players
#    ✅ Success: 31 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [4/20] Processing Brentford (ID: cd051869)
# Fetching wages for Brentford...
# URL: https://fbref.com/en/squads/cd051869/2025-2026/wages/Brentford-Wage-Details
# ✅ Found wages table for Brentford
# ✅ DataFrame created with 32 players
#    ✅ Success: 32 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [5/20] Processing Brighton (ID: d07537b9)
# Fetching wages for Brighton...
# URL: https://fbref.com/en/squads/d07537b9/2025-2026/wages/Brighton-Wage-Details
# ✅ Found wages table for Brighton
# ✅ DataFrame created with 43 players
#    ✅ Success: 43 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [6/20] Processing Burnley (ID: 943e8050)
# Fetching wages for Burnley...
# URL: https://fbref.com/en/squads/943e8050/2025-2026/wages/Burnley-Wage-Details
# ✅ Found wages table for Burnley
# ✅ DataFrame created with 36 players
#    ✅ Success: 36 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [7/20] Processing Chelsea (ID: cff3d9bb)
# Fetching wages for Chelsea...
# URL: https://fbref.com/en/squads/cff3d9bb/2025-2026/wages/Chelsea-Wage-Details
# ✅ Found wages table for Chelsea
# ✅ DataFrame created with 41 players
#    ✅ Success: 41 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [8/20] Processing Crystal Palace (ID: 47c64c55)
# Fetching wages for Crystal Palace...
# URL: https://fbref.com/en/squads/47c64c55/2025-2026/wages/Crystal Palace-Wage-Details
# ✅ Found wages table for Crystal Palace
# ✅ DataFrame created with 31 players
#    ✅ Success: 31 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [9/20] Processing Everton (ID: d3fd31cc)
# Fetching wages for Everton...
# URL: https://fbref.com/en/squads/d3fd31cc/2025-2026/wages/Everton-Wage-Details
# ✅ Found wages table for Everton
# ✅ DataFrame created with 20 players
#    ✅ Success: 20 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [10/20] Processing Fulham (ID: fd962109)
# Fetching wages for Fulham...
# URL: https://fbref.com/en/squads/fd962109/2025-2026/wages/Fulham-Wage-Details
# ✅ Found wages table for Fulham
# ✅ DataFrame created with 24 players
#    ✅ Success: 24 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [11/20] Processing Leeds United (ID: 5bfb9659)
# Fetching wages for Leeds United...
# URL: https://fbref.com/en/squads/5bfb9659/2025-2026/wages/Leeds United-Wage-Details
# ✅ Found wages table for Leeds United
# ✅ DataFrame created with 28 players
#    ✅ Success: 28 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [12/20] Processing Liverpool (ID: 822bd0ba)
# Fetching wages for Liverpool...
# URL: https://fbref.com/en/squads/822bd0ba/2025-2026/wages/Liverpool-Wage-Details
# ✅ Found wages table for Liverpool
# ✅ DataFrame created with 29 players
#    ✅ Success: 29 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [13/20] Processing Manchester City (ID: b8fd03ef)
# Fetching wages for Manchester City...
# URL: https://fbref.com/en/squads/b8fd03ef/2025-2026/wages/Manchester City-Wage-Details
# ✅ Found wages table for Manchester City
# ✅ DataFrame created with 35 players
#    ✅ Success: 35 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [14/20] Processing Manchester Utd (ID: 19538871)
# Fetching wages for Manchester Utd...
# URL: https://fbref.com/en/squads/19538871/2025-2026/wages/Manchester Utd-Wage-Details
# ✅ Found wages table for Manchester Utd
# ✅ DataFrame created with 33 players
#    ✅ Success: 33 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [15/20] Processing Newcastle Utd (ID: b2b47a98)
# Fetching wages for Newcastle Utd...
# URL: https://fbref.com/en/squads/b2b47a98/2025-2026/wages/Newcastle Utd-Wage-Details
# ✅ Found wages table for Newcastle Utd
# ✅ DataFrame created with 29 players
#    ✅ Success: 29 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [16/20] Processing Nott'ham Forest (ID: e4a775cb)
# Fetching wages for Nott'ham Forest...
# URL: https://fbref.com/en/squads/e4a775cb/2025-2026/wages/Nott'ham Forest-Wage-Details
# ✅ Found wages table for Nott'ham Forest
# ✅ DataFrame created with 30 players
#    ✅ Success: 30 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [17/20] Processing Sunderland (ID: 8ef52968)
# Fetching wages for Sunderland...
# URL: https://fbref.com/en/squads/8ef52968/2025-2026/wages/Sunderland-Wage-Details
# ✅ Found wages table for Sunderland
# ✅ DataFrame created with 32 players
#    ✅ Success: 32 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [18/20] Processing Tottenham (ID: 361ca564)
# Fetching wages for Tottenham...
# URL: https://fbref.com/en/squads/361ca564/2025-2026/wages/Tottenham-Wage-Details
# ✅ Found wages table for Tottenham
# ✅ DataFrame created with 34 players
#    ✅ Success: 34 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [19/20] Processing West Ham (ID: 7c21e445)
# Fetching wages for West Ham...
# URL: https://fbref.com/en/squads/7c21e445/2025-2026/wages/West Ham-Wage-Details
# ✅ Found wages table for West Ham
# ✅ DataFrame created with 24 players
#    ✅ Success: 24 players added
#    ⏳ Waiting before next request...
#
# 🏟️  [20/20] Processing Wolves (ID: 8cec06e1)
# Fetching wages for Wolves...
# URL: https://fbref.com/en/squads/8cec06e1/2025-2026/wages/Wolves-Wage-Details
# ✅ Found wages table for Wolves
# ✅ DataFrame created with 33 players
#    ✅ Success: 33 players added
# \n📊 Combining data from 20 successful extractions...
# \n================================================================================
# 📈 EXTRACTION SUMMARY:
#    Total teams processed: 20
#    Successful extractions: 20
#    Failed extractions: 0
#    Total players in dataset: 622
#    Columns in dataset: 10
# ================================================================================
# \n✅ Success! Combined wages dataset created
# Shape: (622, 10)
# Columns: ['player', 'nationality', 'position', 'age', 'weekly_wages', 'annual_wages', 'notes', 'team_name', 'team_id', 'season']
# \n💾 Data saved to inference/raw/ directory in multiple formats
# \n📋 Sample data:
#   team_name               player age                     weekly_wages  \
# 0   Arsenal          Kai Havertz  26  £ 280,000 (€ 321,368, $371,011)
# 1   Arsenal        Gabriel Jesus  28  £ 265,000 (€ 304,152, $351,136)
# 2   Arsenal          Declan Rice  26  £ 240,000 (€ 275,458, $318,010)
# 3   Arsenal      Martin Ødegaard  26  £ 240,000 (€ 275,458, $318,010)
# 4   Arsenal      Viktor Gyökeres  27  £ 200,000 (€ 229,548, $265,008)
# 5   Arsenal          Bukayo Saka  23  £ 195,000 (€ 223,810, $258,383)
# 6   Arsenal       William Saliba  24  £ 190,000 (€ 218,071, $251,758)
# 7   Arsenal   Gabriel Martinelli  24  £ 180,000 (€ 206,594, $238,507)
# 8   Arsenal  Oleksandr Zinchenko  28  £ 150,000 (€ 172,161, $198,756)
# 9   Arsenal            Ben White  27  £ 150,000 (€ 172,161, $198,756)
#
#                                annual_wages
# 0  £ 14,560,000 (€ 16,711,124, $19,292,582)
# 1  £ 13,780,000 (€ 15,815,885, $18,259,051)
# 2  £ 12,480,000 (€ 14,323,820, $16,536,499)
# 3  £ 12,480,000 (€ 14,323,820, $16,536,499)
# 4  £ 10,400,000 (€ 11,936,517, $13,780,416)
# 5  £ 10,140,000 (€ 11,638,104, $13,435,906)
# 6   £ 9,880,000 (€ 11,339,691, $13,091,395)
# 7   £ 9,360,000 (€ 10,742,865, $12,402,374)
# 8    £ 7,800,000 (€ 8,952,388, $10,335,312)
# 9    £ 7,800,000 (€ 8,952,388, $10,335,312)

# %%
# Out:
#                player nationality position age  \
# 0         Kai Havertz      de GER       CF  26
# 1       Gabriel Jesus      br BRA       CF  28
# 2         Declan Rice     eng ENG       CM  26
# 3     Martin Ødegaard      no NOR       AM  26
# 4     Viktor Gyökeres      se SWE       CF  27
# ..                ...         ...      ...  ..
# 617  Bastien Meupiyou                   CB  19
# 618     Nathan Fraser                   CF  20
# 619   Tawanda Chirewa                   AM  21
# 620        Jhon Arias      co COL       RW  27
# 621         Fer López                   RW  21
#
#                         weekly_wages  \
# 0    £ 280,000 (€ 321,368, $371,011)
# 1    £ 265,000 (€ 304,152, $351,136)
# 2    £ 240,000 (€ 275,458, $318,010)
# 3    £ 240,000 (€ 275,458, $318,010)
# 4    £ 200,000 (€ 229,548, $265,008)
# ..                               ...
# 617       £ 8,000 (€ 9,182, $10,600)
# 618        £ 2,500 (€ 2,869, $3,313)
# 619        £ 2,000 (€ 2,295, $2,650)
# 620
# 621
#
#                                  annual_wages                  notes  \
# 0    £ 14,560,000 (€ 16,711,124, $19,292,582)
# 1    £ 13,780,000 (€ 15,815,885, $18,259,051)
# 2    £ 12,480,000 (€ 14,323,820, $16,536,499)
# 3    £ 12,480,000 (€ 14,323,820, $16,536,499)
# 4    £ 10,400,000 (€ 11,936,517, $13,780,416)  Unverified estimation
# ..                                        ...                    ...
# 617           £ 416,000 (€ 477,461, $551,217)  Unverified estimation
# 618           £ 130,000 (€ 149,206, $172,255)  Unverified estimation
# 619           £ 104,000 (€ 119,365, $137,804)  Unverified estimation
# 620
# 621
#
#     team_name   team_id     season
# 0     Arsenal  18bb7c10  2025-2026
# 1     Arsenal  18bb7c10  2025-2026
# 2     Arsenal  18bb7c10  2025-2026
# 3     Arsenal  18bb7c10  2025-2026
# 4     Arsenal  18bb7c10  2025-2026
# ..        ...       ...        ...
# 617    Wolves  8cec06e1  2025-2026
# 618    Wolves  8cec06e1  2025-2026
# 619    Wolves  8cec06e1  2025-2026
# 620    Wolves  8cec06e1  2025-2026
# 621    Wolves  8cec06e1  2025-2026
#
# [622 rows x 10 columns]
